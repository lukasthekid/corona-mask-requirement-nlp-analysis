# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('../../data/p_comment_250.csv')
df2 = pd.read_csv('../../data/p_comment_250-500.csv')
print(df1.shape)
print(df2.shape)
df1.head()
# Out:
# (250000, 11)
# (171572, 11)
#    ID_Posting  ID_Posting_Parent  ID_GodotObject  ID_CommunityIdentity  \
# 0  1049737336                 -1   2000114365338                568012
# 1  1049737620         1049737336   2000114365338                505220
# 2  1049737708                 -1   2000114365338                508661
# 3  1049737722                 -1   2000114365338                583906
# 4  1049737801         1049737746   2000114365338                635467
#
#    id_posting_status Headline  \
# 0                1.0      NaN
# 1                1.0      NaN
# 2                1.0      NaN
# 3                1.0      NaN
# 4                1.0      NaN
#
#                                              Comment                createdAt  \
# 0  Das Virus ist wohl doch VIEL ansteckender als ...  2020-02-10 08:48:31.513
# 1  So ist es, somit sind bestimmt auch deutlich m...  2020-02-10 08:59:34.357
# 2  Das ist für mich eine Horrorvorstellung. Final...  2020-02-10 09:03:20.527
# ...

# %%
frames = [df1, df2]
result = pd.concat(frames)
#result.to_csv('../data/p_comment.csv', encoding='utf-8', index=False)
result.to_pickle('../data/p_comment.pkl.zip', compression='infer')

# %%
df = pd.read_pickle('../data/p_comment.pkl.zip')
print(df.shape)
df.head()
# Out:
# (421572, 11)
#    ID_Posting  ID_Posting_Parent  ID_GodotObject  ID_CommunityIdentity  \
# 0  1049737336                 -1   2000114365338                568012
# 1  1049737620         1049737336   2000114365338                505220
# 2  1049737708                 -1   2000114365338                508661
# 3  1049737722                 -1   2000114365338                583906
# 4  1049737801         1049737746   2000114365338                635467
#
#    id_posting_status Headline  \
# 0                1.0      NaN
# 1                1.0      NaN
# 2                1.0      NaN
# 3                1.0      NaN
# 4                1.0      NaN
#
#                                              Comment                createdAt  \
# 0  Das Virus ist wohl doch VIEL ansteckender als ...  2020-02-10 08:48:31.513
# 1  So ist es, somit sind bestimmt auch deutlich m...  2020-02-10 08:59:34.357
# 2  Das ist für mich eine Horrorvorstellung. Final...  2020-02-10 09:03:20.527
# ...
