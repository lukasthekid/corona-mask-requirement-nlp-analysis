# %%
import pandas as pd
import numpy as np
import spacy
from spacy_sentiws import spaCySentiWS

# %%
df = pd.read_csv('data/p_content.csv')
df.head()
# Out:
#    ID_GodotObject                                                url  \
# 0   2000115059032  /2000115059032/Maskenpflicht-fuer-medizinische...
# 1   2000116305030  /jetzt/livebericht/2000116305030/regierung-zie...
# 2   2000116325081  /2000116325081/Regierung-stellt-weitere-Corona...
# 3   2000116346340  /jetzt/livebericht/2000116346340/schrittweise-...
# 4   2000116371728  /jetzt/livebericht/2000116371728/mittwoch-um-1...
#
#            author  RessortName     source sourceCategory   ObjectType  \
# 0  (keine Angabe)  Coronavirus  Redaktion    Online only      Artikel
# 1  (keine Angabe)  Coronavirus  Redaktion    Online only  LiveBericht
# 2  (keine Angabe)  Coronavirus  Redaktion    Online only      Artikel
# 3  (keine Angabe)  Coronavirus  Redaktion    Online only  LiveBericht
# 4  (keine Angabe)  Coronavirus  Redaktion    Online only     LiveChat
#
#             publishingDate                                          titletext  \
# 0  2020-02-26 16:50:27.000  Maskenpflicht für medizinisches Personal im Um...
# 1  2020-03-30 05:36:31.240  Schrittweise Einführung von Maskenpflicht in d...
# 2  2020-03-30 13:17:32.120  Regierung setzt auf Masken beim Einkauf, Tests...
# 3  2020-03-31 05:34:39.260  Maskenpflicht im Supermarkt spätestens ab Mont...
# 4  2020-03-31 16:15:23.100  Sonderbeauftragter Clemens Auer: "Italienische...
#
#                                              content
# 0  ﻿2.0Sars-CoV-2Maskenpflicht für medizinisches ...
# 1  ﻿2.0CoronavirusSchrittweise Einführung von Mas...
# 2  ﻿2.0Kein Ende in SichtRegierung setzt auf Mask...
# 3  ﻿2.0CoronavirusMaskenpflicht im Supermarkt spä...
# 4  ﻿2.0CoronavirusSonderbeauftragter Clemens Auer...

# %% [markdown]
# https://github.com/Liebeck/spacy-sentiws

# %%
nlp = spacy.load('de_core_news_sm')
nlp.add_pipe('sentiws',config={'sentiws_path': 'data/sentiws/'})
doc = nlp('Die Dummheit der Unterwerfung blüht in hübschen Farben.')

# Initialize a variable to store the overall sentiment score
sentiment_score = 0
for token in doc:
    print('{}, {}, {}'.format(token.text, token._.sentiws, token.pos_))
    sentiment_score += token._.sentiws or 0
    
print(sentiment_score)
# Out:
# Die, None, DET
# Dummheit, -0.4877, NOUN
# der, None, DET
# Unterwerfung, -0.3279, NOUN
# blüht, 0.2028, VERB
# in, None, ADP
# hübschen, 0.4629, ADJ
# Farben, None, NOUN
# ., None, PUNCT
# -0.14990000000000014

# %% [markdown]
# Now on the Whole DataFrame

# %%
def get_overall_sentiment(text):
    doc = nlp(text)
    sentiment_score = 0
    for token in doc:
        #print('{}, {}, {}'.format(token.text, token._.sentiws, token.pos_))
        sentiment_score += token._.sentiws or 0
    
    return sentiment_score / len(doc)


df['sentiment_content'] = df['content'].apply(lambda x: get_overall_sentiment(str(x)))
df['sentiment_titletext'] = df['titletext'].apply(lambda x: get_overall_sentiment(str(x)))

df.head()
# Out:
#    ID_GodotObject                                                url  \
# 0   2000115059032  /2000115059032/Maskenpflicht-fuer-medizinische...
# 1   2000116305030  /jetzt/livebericht/2000116305030/regierung-zie...
# 2   2000116325081  /2000116325081/Regierung-stellt-weitere-Corona...
# 3   2000116346340  /jetzt/livebericht/2000116346340/schrittweise-...
# 4   2000116371728  /jetzt/livebericht/2000116371728/mittwoch-um-1...
#
#            author  RessortName     source sourceCategory   ObjectType  \
# 0  (keine Angabe)  Coronavirus  Redaktion    Online only      Artikel
# 1  (keine Angabe)  Coronavirus  Redaktion    Online only  LiveBericht
# 2  (keine Angabe)  Coronavirus  Redaktion    Online only      Artikel
# 3  (keine Angabe)  Coronavirus  Redaktion    Online only  LiveBericht
# 4  (keine Angabe)  Coronavirus  Redaktion    Online only     LiveChat
#
#             publishingDate                                          titletext  \
# 0  2020-02-26 16:50:27.000  Maskenpflicht für medizinisches Personal im Um...
# 1  2020-03-30 05:36:31.240  Schrittweise Einführung von Maskenpflicht in d...
# 2  2020-03-30 13:17:32.120  Regierung setzt auf Masken beim Einkauf, Tests...
# 3  2020-03-31 05:34:39.260  Maskenpflicht im Supermarkt spätestens ab Mont...
# 4  2020-03-31 16:15:23.100  Sonderbeauftragter Clemens Auer: "Italienische...
#
#                                              content  sentiment_content  \
# 0  ﻿2.0Sars-CoV-2Maskenpflicht für medizinisches ...          -0.006165
# 1  ﻿2.0CoronavirusSchrittweise Einführung von Mas...           0.001257
# 2  ﻿2.0Kein Ende in SichtRegierung setzt auf Mask...          -0.001846
# 3  ﻿2.0CoronavirusMaskenpflicht im Supermarkt spä...           0.000411
# 4  ﻿2.0CoronavirusSonderbeauftragter Clemens Auer...          -0.001826
#
#    sentiment_titletext
# 0             0.000000
# 1             0.000000
# 2             0.000333
# 3             0.000000
# 4            -0.047864

# %%
df.to_csv('data/feature/sentiws_content.csv', encoding='utf-8', index=False)
