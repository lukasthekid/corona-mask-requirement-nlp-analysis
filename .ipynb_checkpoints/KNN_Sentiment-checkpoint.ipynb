# %%
import pandas as pd
import numpy as np
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import MiniBatchKMeans

from collections import Counter 
from sklearn.metrics import silhouette_samples, silhouette_score
import os
import random
import re

SEED = 42
random.seed(SEED)
np.random.seed(SEED)

# %% [markdown]
# Lemmatizing was used in the Preprocessing now we will do word embedding
# https://stackoverflow.com/questions/23877375/word2vec-lemmatization-of-corpus-before-training

# %%
df = pd.read_csv('data/p_content.csv')
df1 = df[['ID_GodotObject','content','titletext']]
print(df1.shape)
df1.head()
# Out:
# (103, 3)
#    ID_GodotObject                                            content  \
# 0   2000115059032  medizinisch Personal Umgang Labor müssen Probe...
# 1   2000116305030  Einführung Maskenpflicht Regierung verschärfen...
# 2   2000116325081  Ende Sicht Regierung setzen Maske bei Einkauf ...
# 3   2000116346340  Supermarkt spätestens ab Montag Entscheidung M...
# 4   2000116371728  Clemens Auer italienisch spanisch Verhältnis v...
#
#                                            titletext
# 0  Maskenpflicht medizinisch Personal Umgang Coro...
# 1  schrittweise Einführung Maskenpflicht Öffentli...
# 2  Regierung setzen Maske bei Einkauf Test Freist...
# 3  Maskenpflicht Supermarkt spätestens ab Montag ...
# 4  Sonderbeauftragter Clemens Auer italienisch sp...

# %% [markdown]
# The model produces high-dimensional vectors, where the size parameter sets the number of dimensions. The optimal number of dimensions depends on the size of the dataset. In our case, 100 dimensions seem to be working very well. min_count parameter controls the minimum frequency of words.
#
#
#
# https://dylancastillo.co/nlp-snippets-cluster-documents-using-word2vec/
#
#
# ## Apply function to remove duplicates

# %%
text_columns = ["content", "titletext"]
df1["merged_text"] = df1[text_columns].apply(lambda x: " | ".join(x), axis=1)
df1["tokens"] = df1["merged_text"].map(lambda x: x.split())

# Remove duplicated after preprocessing
_, idx = np.unique(df1["tokens"], return_index=True)
df1 = df1.iloc[idx, :]

print(df1.shape)
df1.head()
# Out:
# (103, 5)
# /var/folders/1_/83qhk9ps6fd0yym23nn9nfz00000gn/T/ipykernel_59504/1861739798.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["merged_text"] = df1[text_columns].apply(lambda x: " | ".join(x), axis=1)
# /var/folders/1_/83qhk9ps6fd0yym23nn9nfz00000gn/T/ipykernel_59504/1861739798.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["tokens"] = df1["merged_text"].map(lambda x: x.split())
#     ID_GodotObject                                            content  \
# 84   2000128312219  50 Teilnehmer begräbnissen letzter Abschied se...
# 37   2000120217222  Ampel Wien bleiben Orang acht neu Bezirk Orang...
# 7    2000116717900  Anton bleiben Quarantan fast fünfte freiwillig...
# 48   2000122442386  Antwort wie vieler Mensch Weihnachten Silveste...
# 67   2000124163685  Anzeige Samstag Polizei nehmen fünf Person fes...
#
#                                             titletext  \
# 84  VfGH 50 Teilnehmer begräbnissen unverhältnismäßig
# 37  neu Ampel Wien bleiben Orang acht neu Bezirk O...
# 7   Paznaun Anton bleiben Quarantan fast fünfte fr...
# 48  wie vieler Mensch Weihnachten Silvester Werkta...
# 67                               Anzeige Samstag Wien
#
#                                           merged_text  \
# 84  50 Teilnehmer begräbnissen letzter Abschied se...
# 37  Ampel Wien bleiben Orang acht neu Bezirk Orang...
# 7   Anton bleiben Quarantan fast fünfte freiwillig...
# 48  Antwort wie vieler Mensch Weihnachten Silveste...
# 67  Anzeige Samstag Polizei nehmen fünf Person fes...
#
#                                                tokens
# 84  [50, Teilnehmer, begräbnissen, letzter, Abschi...
# 37  [Ampel, Wien, bleiben, Orang, acht, neu, Bezir...
# 7   [Anton, bleiben, Quarantan, fast, fünfte, frei...
# 48  [Antwort, wie, vieler, Mensch, Weihnachten, Si...
# 67  [Anzeige, Samstag, Polizei, nehmen, fünf, Pers...

# %% [markdown]
# ### Check for common words

# %%
docs = df1["merged_text"].values
tokenized_docs = df1["tokens"].values
ids = df1["ID_GodotObject"].values
vocab = Counter()
for token in tokenized_docs:
    vocab.update(token)
    
vocab.most_common(10)
# Out:
# [('der', 808),
#  ('werden', 246),
#  ('Foto', 244),
#  ('in', 221),
#  ('ab', 204),
#  ('Wien', 201),
#  ('gelten', 198),
#  ('sein', 197),
#  ('Maskenpflicht', 194),
#  ('mehr', 191)]

# %% [markdown]
# ### Generate Vectors from document

# %%
def vectorize(list_of_docs, model):
    """Generate vectors for list of documents using a Word Embedding

    Args:
        list_of_docs: List of documents
        model: Gensim's Word Embedding

    Returns:
        List of document vectors
    """
    features = []

    for tokens in list_of_docs:
        zero_vector = np.zeros(model.vector_size)
        vectors = []
        for token in tokens:
            if token in model.wv:
                try:
                    vectors.append(model.wv[token])
                except KeyError:
                    continue
        if vectors:
            vectors = np.asarray(vectors)
            avg_vec = vectors.mean(axis=0)
            features.append(avg_vec)
        else:
            features.append(zero_vector)
    return features

# %%
model = Word2Vec(sentences=tokenized_docs, vector_size=100, workers=1, seed=42)
model.wv.most_similar("Maske")
# Out:
# [('der', 0.9998356699943542),
#  ('in', 0.9998061060905457),
#  ('bei', 0.999804675579071),
#  ('werden', 0.9998003840446472),
#  ('mehr', 0.9997920989990234),
#  ('geben', 0.9997724890708923),
#  ('dürfen', 0.9997721314430237),
#  ('neu', 0.9997711181640625),
#  ('können', 0.9997584223747253),
#  ('bleiben', 0.9997560381889343)]

# %%
vectorized_docs = vectorize(tokenized_docs, model=model)
len(vectorized_docs), len(vectorized_docs[0])
# Out:
# ['50', 'Teilnehmer', 'begräbnissen', 'letzter', 'Abschied', 'sein', 'weder', 'substituierbar', 'begründen', 'VfGH', 'verhältnismäßig', 'indes', 'Maskenpflicht', 'Handel', 'Wien', 'der', 'Verfassungsgerichtshof', 'VfGH', 'mehrere', 'Entscheidung', 'Beschwerde', 'Zusammenhang', 'treffen', 'Stattgegebe', 'VfGH', 'Beschwerde', 'begräbnissen', 'der', 'Beschränkung', '50', 'Teilnehmer', 'unverhältnismäßig', 'befinden', 'Höchstrichter', 'Auswirkung', 'Entscheidung', 'freilich', 'mehr', 'Schwerer', 'Eingriff', 'Recht', 'Privatleben', 'der', 'zweiter', 'verfassungswidrig', 'erklären', 'Bestimmung', 'enthalten', 'längst', 'mehr', 'Kraft', 'ein', 'Oberösterreicherin', 'können', 'Begräbnis', 'Tante', 'teilnehmen', 'Teil', 'Verordnung', 'angefochten', 'ab', '26', 'Dezember', '2020', 'Woche', 'Kraft', 'der', 'Beschränkung', 'VfGH', 'gesamthaft', 'Betrachtung', 'unverhältnismäßig', 'zwar', 'verfolgt', 'Maßnahme', 'legitim', 'Ziel', 'geeignet', 'jedoch', 'letzter', 'Verabschiedung', 'nahestehend', 'verstorbener', 'weder', 'substituierbar', 'stellen', 'daher', 'besonders', 'schwer', 'Eingriff', 'Recht', 'Privatleben', 'dar', 'ganztägig', 'Ausgangsbeschränkung', 'Legitim', 'hingegen', 'erachten', 'VfGH', 'Verbot', 'betreten', 'Befahren', 'Kundenbereich', 'Betriebsstätt', 'Inanspruchnahme', 'körpernah', 'Dienstleistung', 'Beispiel', 'Massage', 'Oberösterreicherin', 'angefochten', 'Hinblick', 'damalig', 'epidemiologisch', 'Verhältnis', 'sachlich', 'rechtfertigen', 'ebenso', 'ab', '26', 'Dezember', '2020', 'geltend', 'ganztägig', 'Ausgangsbeschränkung', 'Verhältnismäßig', 'Ausreisetestpflicht', 'der', 'Testpflicht', 'Ausreis', 'Tirol', 'beziehungsweise', 'Tiroler', 'Bezirk', 'Kufstein', 'Schwaz', 'Februar', 'beziehungsweise', 'März', '2021', 'ebenfalls', 'Gesetzeskonform', 'befinden', 'VfGH', 'der', 'Gericht', 'Antrag', 'mehrere', 'Einzelperson', 'sowie', 'Landesverwaltungsgericht', 'Tirol', 'Infrag', 'stellen', 'abweisen', 'dieser', 'Einschränkung', 'Recht', 'Freizügigkeit', 'Schutz', 'Verbreitung', 'bestimmt', 'Virusvariante', 'südafrikanisch', 'beziehungsweise', 'britisch', 'Mutation', 'verhältnismäßig', 'Begründen', 'Maskenpflicht', 'Handel', 'abgewiesen', 'werden', 'Antrag', 'Landesverwaltungsgerichts', 'Niederösterreich', 'Feststellung', 'Verpflichtung', 'tragen', 'Kundenbereich', 'Geschlossen', 'Raum', 'Betriebsstätt', 'gesetzwidrig', 'dieser', 'Bestimmung', 'einschließlich', '20', 'September', '2020', 'Kraft', 'ein', 'ähnlich', 'früh', 'Antrag', 'Landesverwaltungsgerichts', 'Niederösterreich', 'beziehen', 'Stammfassung', 'aufgrund', 'Mai', '2020', 'Maskenpflicht', 'Handel', 'gelten', 'in', 'Fall', 'Gesundheitsminister', 'verabsäumen', 'nachvollziehbar', 'festhalten', 'warum', 'Handel', 'geltend', 'Maskenpflicht', 'erforderlich', 'halten', 'dieser', 'Bestimmung', 'daher', 'gesetzwidrig', 'dieser', 'mal', 'Gesundheitsministerium', 'jedoch', 'hinreichend', 'darlegen', 'aufgrund', 'tatsächlich', 'Umstand', 'strittig', 'Regelung', 'erfolgen', 'Maskenpflicht', 'verstieß', 'daher', 'Click', '--', 'Collect', 'verhältnismäßig', 'erfolglos', 'bleiben', 'Antrag', 'Handelskett', 'Ikea', 'Verbot', 'betreten', 'Befahren', 'Kundenbereich', 'Betriebsstätt', 'Handel', 'Verbot', 'Click', '--', 'Collect', 'November', '2020', 'angefochten', 'abholen', 'bereits', 'bezahlt', 'Ware', 'der', 'VfGH', 'stellen', 'fest', 'Verbot', 'verbunden', 'Eingriff', 'Grundrecht', 'Erwerbsfreiheit', 'beziehungsweise', 'Eigentumsgrundrecht', 'angesichts', 'epidemiologisch', 'Lage', 'verhältnismäßig', 'zumal', 'angefochtener', 'Verbot', 'Zeitraum', 'zehn', 'Tag', 'gelten', 'Onlinehandel', 'Zeitpunkt', 'untersagen', 'der', 'VfGH', 'verweisen', 'Entscheidung', 'darauf', 'Gesundheitsminister', 'zuvor', 'versuchen', 'Verbreitung', 'Anordnung', 'Gelinderer', 'Maßnahme', 'verhindern', 'der', 'VfGH', 'erkennen', 'unsachlich', 'Ungleichbehandlung', 'darin', 'gleich', 'Zeitraum', 'Abholung', 'Speise', 'Getränk', 'erlauben', 'der', 'ständig', 'Verfügbarkeit', 'Gut', 'Grundversorgung', 'ess ...
# ['Ampel', 'Wien', 'bleiben', 'Orang', 'acht', 'neu', 'Bezirk', 'Orang', 'eingefärbtCoronaviru', 'warnen', 'Reise', 'Prag', 'Israel', 'Teil', 'Frankreich', 'der', 'Wichtigste', 'Kürze', 'Ampel', 'bleiben', 'Wien', 'Orang', 'acht', 'neu', 'Bezirk', 'Orang', 'einfärben', 'ab', 'Montag', 'herrschen', 'Wiener', 'Gastronomiebetriebe', 'Registrierungspflicht', 'Gast', 'Wirt', 'müssen', 'dafür', 'Formblätter', 'auflegen', 'sagen', 'Bürgermeister', 'Michael', 'Ludwig', 'Donnerstag', 'der', 'Außenministerium', 'Donnerstag', 'Reisewarnung', 'Prag', 'französisch', 'Region', 'aussprechen', 'ab', 'Montag', 'Reise', 'Region', 'abgeraen', 'heißen', 'Seite', 'Außenministerium', 'weit', 'Reisewarnung', 'werden', 'Andorra', 'Israel', 'Argentinien', 'Bahrain', 'Kuwait', 'Costa', 'Rica', 'malediven', 'aussprechen', 'damit', 'gelten', 'österreichisch', 'Reisewarnung', '37', 'Land', 'weltweit', 'gleichzeitig', 'geben', 'Reiseerleichterung', 'der', 'Reisewarnung', 'Schweden', 'aufheben', 'Portugal', 'gelten', 'ab', 'Montag', 'mehr', 'Region', 'Lissabon', 'Norte', 'der', 'Regierung', 'Donnerstagvormittag', 'Aussicht', 'Wintertourismus', 'präsentieren', 'bei', 'Konsumation', 'Getränk', 'Speise', 'drinnen', 'freie', 'Sitzplatzpflicht', 'herrschen', 'zudem', 'bleiben', 'Geschlossen', 'Gondelbahn', 'Maskenpflicht', 'aufrecht', 'Skischule', 'gelten', 'maximal', 'Gruppengröße', 'zehn', 'Person', 'Christkindlmärkt', 'stattfinden', 'Betreiber', 'umfassend', 'Hygienekonzept', 'vorlegen', 'in', 'Frühjahr', 'werden', 'Ischgl', 'Tirol', 'es', 'tun', 'Leid', 'Leid', 'sagen', 'Landeshauptmann', 'Günther', 'Platter', 'ÖVP', 'Donnerstag', 'Frage', 'deutsch', 'Journalistin', 'warum', 'Schwerfalle', 'Zusammenhang', 'Wort', 'Entschuldigung', 'Mund', 'nehmen', 'ein', 'Person', 'alleine', 'sein', 'Pandemie', 'verantwortlich', 'Platter', 'zuletzt', 'Verbraucherschützer', 'Peter', 'Kolba', 'kritisieren', 'Entschuldigung', 'überfällig', 'sein', 'sein', 'Verein', 'Mittwoch', 'erster', 'Amtshaftungsklag', 'Republik', 'einbringen', 'der', 'Zahl', 'neu', 'Coronavirus', 'infiziert', 'Person', 'Österreich', 'Donnerstag', 'steigen', '832', 'Mensch', 'werden', 'positiv', 'testen', 'mit', 'Abstand', 'meister', 'Fall', 'verzeichnen', '431', 'Wien', 'Wirtschaftsministerin', 'Margarete', 'Schramböck', 'ÖVP', 'seit', 'Donnerstag', 'Grund', 'positiv', 'Fall', 'bei', 'Montag', 'Schramböck', 'werden', 'negativ', 'testen', 'auch', 'Deutschland', 'befinden', 'zwei', 'Minister', 'Quarantan', 'Außenminister', 'Heiko', 'Maas', 'SPD', 'Wirtschaftsminister', 'Peter', 'Altmaier', 'CDU', 'Belgien', 'verhängen', 'Reisewarnung', 'Tirol', 'Vorarlberg', 'gültig', 'ab', 'Freitag', 'Deutschland', 'warnen', 'ab', 'sofort', 'Reise', 'Vorarlberg', 'der', 'neu', 'Stimme', 'Koalition', 'SPÖ', 'Mittwoch', 'Nationalrat', 'passieren', 'der', 'neu', 'Regelwerk', 'stellen', 'etwa', 'klar', 'wann', 'Lockdown', 'möglich', 'Art', 'Ausgangsbeschränkung', 'gangbar', 'funktionieren', 'der', 'Zahl', 'Infektion', 'Europa', 'Schwelle', 'fünf', 'Million', 'überschreiten', 'der', 'Zahl', 'Virustot', 'USA', 'Dienstag', 'Marke', 'überspringen', 'damit', 'USA', 'messen', 'offiziell', 'Datum', 'Land', 'weltweit', 'stark', 'betroffen', 'Land', 'red', 'Foto', 'HOCHMUTHFoto', 'DIVISEKFoto', 'CORNFoto', 'CORNFoto', 'WIESERFoto', 'Reuters', 'Lisi', 'Niesner', '|', 'neu', 'Ampel', 'Wien', 'bleiben', 'Orang', 'acht', 'neu', 'Bezirk', 'Orang', 'einfärben']
# ['Anton', 'bleiben', 'Quarantan', 'fast', 'fünfte', 'freiwillig', 'Test', 'Zahl', 'Infizieren', 'ganz', 'Österreich', 'bewegen', 'Wahrscheinlichkeit', 'Anfang', 'April', 'Ergebnis', 'der', 'Wichtigste', 'Kürze', 'der', 'Tiroler', 'Paznauntal', 'Anton', 'Arlberg', 'weit', 'zwei', 'Woche', '26', 'April', 'Quarantan', 'bleiben', 'bei', 'Schwerpunktmäßige', 'Testung', '19', 'Prozent', 'Ergebnis', 'positiv', 'rund', 'Test', 'vergangen', 'Tag', 'Freiwilliger', 'Basis', 'Quarantänegebiet', 'durchführen', 'werden', 'der', 'hoch', 'Anzahl', 'positiv', 'Ergebnis', 'sein', 'erwarten', 'rund', 'Drittel', 'Person', 'leicht', 'Symptom', 'lassen', 'Sicherheitshalber', 'testen', 'zwei', 'Drittel', 'Person', 'jedoch', 'Symptom', 'ein', 'Entscheidung', 'ebenfalls', '13', 'April', 'geltend', 'Quarantan', 'Sölden', 'kommend', 'Tag', 'fallen', 'an', 'Freitag', 'präsentieren', 'Wissenschaftsminister', 'Heinz', 'Faßmann', 'ÖVP', 'sowie', 'Günther', 'Ogris', 'Christoph', 'Hofinger', 'Ergebnis', 'demnach', 'betragen', 'Prävalenz', 'Prozent', 'hochrechnen', 'Bevölkerung', 'sein', 'Person', 'infizieren', 'der', 'Konfidenzintervall', 'liegen', 'allerdings', 'Spektrum', 'real', 'Zahl', 'Infizieren', 'Wahrscheinlichkeit', 'bewegen', 'an', 'Studie', 'bereits', 'zuvor', 'Kritik', 'geben', 'Gesundheitsminister', 'Rudolf', 'Anschober', 'grüne', 'sagen', 'Freitagmittag', 'Österreich', 'befinden', 'sicher', 'Seite', 'Spitalskapazitäte', 'betreffen', 'um', 'bleiben', 'appellieren', 'Mensch', 'riskieren', 'Wetter', 'Ostern', 'traditionell', 'verhalten', 'verführ', 'man', 'gehen', 'positiv', 'getesteten', 'Person', '17', 'April', 'heißen', 'gemeinsam', 'Pressekonferenz', 'Anschober', 'Herwig', 'Ostermann', 'der', 'Verhandlung', 'gemeinsam', 'finden', 'Donnerstagabend', 'erfolgreich', 'Ende', 'von', '500', 'Milliarde', 'schwer', 'Rettungspaket', 'sollen', 'Italien', 'Spanien', 'profitieren', 'Geld', 'sollen', 'Gesundheitssystem', 'fließen', 'bei', 'nächster', '23', 'April', 'sollen', 'Finanzminister', 'Paket', 'voranbringen', 'in', 'Nacht', 'Freitag', 'werden', 'mehrere', 'erwarten', 'Verordnung', 'kundgemachen', 'sie', 'enthalten', 'Verlängerung', 'Ausgangsbeschränkung', 'Ende', 'April', 'Maskenpflicht', 'Supermärkt', 'öffentlich', 'verkehrsmitteln', 'Regel', 'Hochzeit', 'Begräbnis', 'schrittweises', 'hochfahren', 'Handel', 'Ausweitung', 'Gesundheitskontrolle', 'Grenzübergang', 'Nachbarland', 'für', 'erkranken', 'britisch', 'Premierminister', 'Boris', 'Johnson', 'Freitag', 'Gesundheitlich', 'bergauf', 'gehen', 'Johnson', 'Montag', 'wegen', 'Intensivstation', 'verlegen', 'werden', 'der', 'können', 'mittlerweile', 'verlassen', 'Johnsons', 'Aufgabe', 'übernehmen', 'zwischenzeitlich', 'Außenminister', 'Dominic', 'Raab', 'der', 'wichtig', 'lauten', 'Bleibe', 'sie', 'weit', 'möglich', 'Haus', 'schränken', 'sie', 'ihr', 'Sozialkontakt', 'einkaufen', 'Grundversorgung', 'gewährleisten', 'gestatten', 'Aufenthalt', 'öffentlich', 'Raum', 'allein', 'Person', 'gemeinsam', 'Haushalt', 'halten', 'sie', 'Abstandsregel', 'mindestens', 'Meter', 'weit', 'Information', 'der', 'Ages', 'beantworten', 'Frage', 'rund', 'Coronavirus', 'Nummer', '0800', '555', '621', 'sollen', 'sie', 'Symptom', 'aufweisen', 'rufen', 'sie', 'landesweit', 'gültig', 'Gesundheitshotline', '1450', 'der', 'wichtig', 'Frage', 'Antwort', 'Coronavirus', 'der', 'aktuell', 'Zahl', 'Coronavirus', 'aktuelle', 'Österreich', 'Ages', 'Bestätigen', 'Fall', 'Testung', 'Österreich', 'Gesundheitsministerium', 'Hinweis', 'Situation', 'verhaltensregeln', 'mehrere', 'Fremdsprachen', 'Integrationsfond', 'red', 'Foto', 'aPAFoto', 'DE', 'MELO', 'MOREIRAFoto', 'Tomasevic', 'Foto', 'ISABEL', 'INFANTES', 'aFPFoto', 'Vanessa', 'Carvalho', 'via', 'aPAFoto', 'Sonia', 'Moskowitz', 'via', 'MOOREFoto', 'Regine', 'Hendrich', 'Foto', 'aPAFoto', 'mAATFoto', 'ap', 'John', 'Minchillo', 'Foto', 'Thomas', 'via', 'Mcdermid', 'Foto', 'LECOCQFoto', 'OLIVER', '|', 'Paznaun', 'Anton', 'bleiben', 'Quarantan', 'fast', 'fünfte', 'freiwillig', 'Test', 'posit ...
# ['Antwort', 'wie', 'vieler', 'Mensch', 'Weihnachten', 'Silvester', 'Werktag', 'treffen', 'wichtig', 'Frage', 'Antwort', 'Feiertage', 'Freitagnacht', 'verkünden', 'Bundeskanzler', 'Sebastian', 'kurz', 'ÖVP', 'Vizekanzler', 'Werner', 'Kogler', 'grüne', 'Feiertage', 'und', 'präsentieren', 'Plan', 'Massentest', 'Anfang', 'kommend', 'Jahr', 'gerade', 'privat', 'Bereich', 'Ansteckung', 'hoch', 'betonen', 'kurz', 'treffen', 'Landeshauptleute', 'und', 'der', 'Virus', 'machen', 'Feiertag', 'Halt', 'der', 'Ansteckungsniveau', 'sein', 'hoch', 'in', 'Jänner', 'Februar', 'März', 'hart', 'Zeit', 'Österreicher', 'zukommen', 'Frage', 'welcher', 'Regelung', 'gelten', 'aktuell', 'wen', 'dürfen', 'derzeit', 'treffen', 'Antwort', 'derzeit', 'gelten', 'schon', 'hart', 'Lockdown', '6', 'Dezember', 'auslaufen', 'Kontaktbeschränkung', 'Ausgangssperr', 'Nacht', 'von', '20', 'Uhr', 'abends', '6', 'Uhr', 'früh', 'dürfen', 'eigen', 'vier', 'Wand', 'Grund', 'verlassen', 'Arbeit', 'Bedürfnis', 'täglich', 'Leben', 'Hilfe', 'Mensch', 'Bewegung', 'frisch', 'Luft', 'tagsüber', 'dürfen', 'hingegen', 'maximal', 'sechs', 'erwachsene', 'plus', 'sechs', 'Kind', 'zwei', 'unterschiedlich', 'Haushalt', 'treffen', 'Frage', 'welcher', 'Regelung', 'gelten', 'Weihnachten', 'Antwort', 'an', 'Weihnachtsfeiertag', 'sollen', 'Ausgangsbeschränkung', 'lockern', 'Familie', 'Tag', 'gemeinsam', 'verbringen', 'an', '25', 'Dezember', 'dürfen', 'daher', 'zehn', 'Person', 'beliebig', 'vieler', 'Haushalt', 'treffen', 'gemeinsam', 'Geschenk', 'auspacken', '20', 'Uhr', 'Frage', 'Gelten', 'Lockerung', 'ganz', 'Weihnachtsfeiertage', 'Antwort', 'ursprünglich', 'andachen', 'wegen', 'weiterhin', 'hoch', 'Infektionsgeschehen', 'entscheiden', 'Bundesregierung', 'jedoch', 'Ausnahme', '25', 'Dezember', 'beschränken', 'an', 'Stefanitag', '26', 'Dezember', 'gelten', 'gewohnt', 'Beschränkung', 'aus', 'zwei', 'Haushalt', 'dürfen', 'maximal', 'sechs', 'erwachsene', 'plus', 'sechs', 'Kind', '20', 'Uhr', 'treffen', 'Frage', 'wie', 'Silvester', 'feiern', 'Antwort', 'auch', 'Jahreswechsel', 'klein', 'Kreis', 'feiern', 'bisher', 'denken', 'für', 'Nacht', '31', 'Dezember', '1', 'Jänner', 'gelten', 'es', 'entfallen', 'nächtlich', 'Ausgangsbeschränkung', 'der', 'heißen', 'wann', 'Nacht', 'Einladung', 'Haus', 'fahren', 'egal', 'jedoch', 'bleiben', 'Kontaktbeschränkung', 'aufrecht', 'der', 'bedeuten', 'Tag', 'maximal', 'zwei', 'Haushalt', 'Größe', 'insgesamt', 'sechs', 'erwachsene', 'plus', 'sechs', 'Kind', 'anstoßen', 'neu', 'Jahr', 'treffen', 'Frage', 'wann', 'Weihnachten', 'Zug', 'Massentest', 'testen', 'lassen', 'Antwort', 'Tirol', 'Vorarlberg', 'Massentestunge', 'bereits', 'abschließen', 'in', 'Bundesland', 'Coronavirus', 'testen', 'lassen', 'in', 'Wien', 'Kärnten', 'Salzburg', 'Niederösterreich', 'Steiermark', 'Sonntag', '13', 'Dezember', 'möglich', 'in', 'Oberösterreich', 'Montag', '14', 'Dezember', 'Zeit', 'in', 'Burgenland', 'Test', 'Dienstag', '15', 'Dezember', 'möglich', 'Frage', 'geben', 'zweiter', 'Antwort', 'ja', 'planen', 'zweiter', 'Durchlauf', 'Anfang', 'Jänner', 'in', 'meister', 'Bundesland', 'Testung', '10', 'Jänner', 'Bühne', 'gehen', 'Wien', 'wegen', 'hoch', 'Bevölkerungszahl', 'lang', 'brauchen', 'darum', '17', 'Jänner', 'ausdehnen', 'Frage', 'geben', 'Möglichkeit', 'Test', 'fest', 'Antwort', 'ja', 'wenn', 'Symptom', 'Bundesland', 'weiterhin', '1450', 'anrufen', 'testen', 'Haben', 'Symptom', 'geben', 'mittlerweile', 'diverser', 'Möglichkeit', 'schnelltest', 'Beispielsweise', 'Apotheke', 'dieser', 'kosten', 'rund', '30', 'Euro', 'dauern', 'halb', 'Stunde', 'Ergebnis', 'vorliegen', 'auch', 'geben', 'groß', 'Bandbreite', 'Schnelltest', 'DER', 'STANDARD', 'davon', 'testen', 'in', 'Wien', 'geben', 'zudem', 'drei', 'gratis', 'Teststraße', 'Stadt', 'der', 'Teststraße', 'bei', 'Donauinsel', 'seit', 'neu', 'Teststraße', 'Austria', 'Center', 'Vienna', 'in', 'Letzterer', 'kommen', 'Einsatz', 'bei', 'beide', 'gurgeln', 'Frage', 'geben', 'Testung', 'bestimmen', 'Berufsgruppe', 'Antwort', 'ja', 'Ausgewe ...
# ['Anzeige', 'Samstag', 'Polizei', 'nehmen', 'fünf', 'Person', 'fest', 'Anzeige', 'geben', 'wegen', 'gering', 'Abstand', 'fehlend', 'Maske', 'trotz', 'verboten', 'Samstag', 'Wien', 'Demonstrierende', 'Regierung', 'zusammenfinden', 'bei', 'Protest', 'rund', 'Anzeige', 'Polizei', 'kommen', 'davon', '18', 'strafrechtlich', 'wegen', 'versuchen', 'Widerstand', 'Staatsgewalt', 'tätlich', 'Angriff', 'Beamter', 'vier', 'Person', 'werden', 'strafrechtlich', 'wegen', 'Verdacht', 'versuchen', 'Widerstand', 'Staatsgewalt', 'Person', 'verwaltungsrechtlich', 'wegen', 'Verstoß', 'festnehmen', 'bilanzieren', 'Polizei', 'bis', 'Teilnehmer', 'der', 'Polizei', 'zählen', 'Teilnehmer', 'mittags', 'Karlskirche', 'treffen', 'Spaziergang', 'Ringstraße', 'starten', 'dort', 'geben', 'Polizeiblockade', 'der', 'Demonstrant', 'Neonazi', 'wandern', 'daraufhin', 'stundenlang', 'Innenstadt', 'dass', 'Neonazi', 'Gottfried', 'Küssel', 'weit', 'Rechtsextremist', 'Kundgebung', 'teilnehmen', 'teils', 'Seite', 'Polizei', 'marschieren', 'sein', 'Beobachter', 'etwa', 'via', 'Twitter', 'monieren', 'bestätigen', 'Sicherheitskraft', 'der', 'Verfassungsschutz', 'sein', 'Einsatz', 'heißen', 'ein', 'Gegendemonstration', 'Linker', 'Aktivist', 'geben', 'insgesamt', 'rund', 'Anzeige', 'stellen', 'Polizei', 'Demo', 'Wien', 'erst', 'Abend', 'Ende', 'in', 'Zug', 'Großeinsatz', 'Polizei', 'mehr', 'Beamtin', 'Beamter', 'kommen', 'Weiter', '675', 'Anzeige', 'wegen', 'Missachtung', 'Mindestabstand', '609', 'Anzeige', 'wegen', 'Verstoß', 'Maskenpflicht', 'zwei', 'Organmandat', 'wegen', 'Verstoß', 'Bestimmung', '288', 'sonstig', 'Verwaltungsstrafanzeige', 'Video', 'Demo', 'Samstag', 'einiger', 'Tiroler', 'marschieren', 'auffällig', 'stark', 'präsent', 'Demonstration', 'Tiroler', 'der', 'Tiroler', 'Adler', 'fliegen', 'wohin', 'heißen', 'münzen', 'Testpflicht', 'verlassen', 'Bundesland', 'Gerufen', 'werden', 'kurz', 'Protest', 'richten', 'gesamt', 'Bundesregierung', 'der', 'Polizei', 'kontrollieren', 'Bus', 'Tirol', 'dabei', 'stellen', 'heraus', '57', 'Person', 'negativ', 'Test', 'vorlegen', 'können', 'Bundesland', 'Regelkonform', 'Test', 'alt', '48', 'Stunde', 'verlassen', 'auch', 'Tiroler', 'verschlagen', 'Bundeshauptstadt', 'Rechtliche', 'Schritt', 'lässen', 'Innenminister', 'Karl', 'Nehammer', 'ÖVP', 'außerdem', 'Rudolf', 'Fußi', 'prüfen', 'dieser', 'Twitter', 'Einsatz', 'Polizeihunde', 'kommentieren', 'meinen', 'der', 'wahrscheinlich', 'intelligent', 'Durchschnittsmitarbeiter', 'LPD', 'Wien', 'Nehammer', 'bezeichnen', 'Äußerung', 'unzumutbar', 'red', 'APA', 'unter', 'wegen', 'Missachtung', 'Mindestabstands', 'Verstoß', 'Maskenpflicht', 'werden', 'Anzeige', 'legen', 'DER', 'STANDARDWieder', 'demonstrieren', 'Tausend', 'Wien', 'unser', 'Videoteam', 'Ort', 'Leute', 'aPAFoto', 'aPAFoto', 'APA', 'Herbert', 'Pfarrhofer', '|', 'Anzeige', 'Samstag', 'Wien']
# ['Arbeitsplatz', 'noch', 'Zeitplan', 'Regel', 'laut', 'Gesundheitsministerium', 'abstimmen', 'zuletzt', 'Touristiker', 'Druck', 'machen', 'rechtlich', 'Rahmenbedingung', 'fordern', 'an', 'Freitag', 'haben', 'Verordnung', 'Arbeitsplatz', 'Parlament', 'beschließen', 'sollen', 'kommen', 'es', 'geben', 'konkret', 'Zeitplan', 'Verordnung', 'heißen', 'Donnerstag', 'Gesundheitsministerium', 'APA', 'der', 'Detail', 'zuständig', 'Ministerium', 'abstimmen', 'sobald', 'Prozess', 'abschließen', 'detailliert', 'Information', 'Regelung', 'Frist', 'bekanntgeben', 'Sprecher', 'ein', 'Anfang', 'Oktober', 'Bekanntgewordener', 'Verordnungsentwurf', '3', 'G', 'impfen', 'genesen', 'testen', 'Arbeitnehmer', 'vorsehen', 'Kontakt', 'Kunde', 'Kollege', 'der', 'Nachweis', 'müssten', 'Arbeitnehmer', 'Arbeitsplatz', 'immer', 'dabei', 'bei', 'direkt', 'Kundenkontakt', 'gelten', 'Ausnahme', 'Gastronomie', 'Sportstätt', 'außerdem', 'Maskenpflicht', 'Infektionsrisiko', 'Schutzmaßnahm', 'minimieren', 'zitieren', 'ZiB', '2', 'Entwurf', 'Regierungskrise', 'kommen', 'dazwischen', 'der', 'Gesundheitsministerium', 'betonen', 'Donnerstag', 'medial', 'bekanntgewordenen', 'Papier', 'lediglich', 'Arbeitsunterlage', 'handeln', 'Druck', 'zuletzt', 'Touristiker', 'skigebieten', 'machen', 'Saisonstart', 'stehen', 'dazu', 'heißen', 'Woche', 'Büro', 'Gesundheitsminister', 'Wolfgang', 'Mückstein', 'grüne', 'Verordnung', 'befinden', 'final', 'Phase', 'allerdings', 'kommen', 'Regierungskrise', 'dazwischen', 'schon', 'September', 'geplant', 'Einführung', 'Arbeitsplatz', 'Irritation', 'sorgen', 'der', 'Regierung', 'verweisen', 'Sozialpartner', 'wiederum', 'spielen', 'Ball', 'zurück', 'wobei', 'Gewerkschaft', 'Wirtschaftskammer', 'grundsätzlich', 'positiv', 'verschärfen', 'Arbeitsplatz', 'bekannt', 'der', 'SPÖ', 'ebenfalls', 'positiv', 'äußern', 'was', 'wirtshaustisch', 'gelten', 'Arbeitsplatz', 'gelten', 'meinen', 'Pamela', 'damals', 'Ablehnung', 'kommen', 'FPÖ', 'in', 'Italien', 'dürfen', 'ab', 'Freitag', 'mehr', 'geimpfter', 'genesene', 'Getestet', 'Arbeitsplatz', 'betreten', 'der', 'teilweise', 'heftig', 'Demonstration', 'führen', 'Impfbereitschaft', 'erhöhen', 'APA', 'der', 'Gesundheitsministerium', 'betonen', 'medial', 'bekanntgewordenen', 'Papier', 'Arbeitsunterlage', 'handeln', 'Foto', 'imago', 'Gudath', '|', 'Arbeitsplatz', 'noch', 'Zeitplan', 'Verordnung']
# ['Arztpraxis', 'gesetzlich', 'verankern', '563', 'Niederösterreich', 'werden', 'mehr', 'Neuinfektion', 'Wien', 'melden', 'in', 'Tschechien', 'Gesundheitsminister', 'Vojtěch', 'zurücktreten', 'der', 'Wichtigste', 'Kürze', 'der', 'Koalition', 'planen', 'weit', 'Gesetzesänderung', 'der', 'Nationalrat', 'etwa', 'Arztpraxis', 'beschließen', 'Kasse', 'Kosten', 'Bundes', 'bezahlen', 'ein', 'entsprechend', 'Antrag', 'Montag', 'Gesundheitsausschuss', 'Richtung', 'Plenum', 'schicken', 'in', 'Nationalrat', 'finden', 'Expertenhearing', 'statt', 'innerhalb', '24', 'Stunde', 'Zahl', 'Österreich', 'zuletzt', '563', 'steigen', 'bisher', 'geben', 'Österreich', 'positiv', 'Testergebnis', 'Niederösterreich', 'liegen', 'diesmal', 'Neuinfektion', 'Wien', 'es', 'verzeichnen', '181', 'Neuinfektion', 'eingemeldeten', 'Test', 'der', 'bedeuten', 'rund', 'Prozent', 'gemeldeen', 'Test', 'positiv', 'der', 'allerdings', 'Nachmeldung', 'liegen', 'an', 'Freitag', 'geben', 'Einmeldung', 'Test', '891', 'stark', 'Ausreißer', 'unten', 'in', 'Wien', 'geben', '172', 'Neuinfektion', 'eingemeldeten', 'Test', 'Trefferquote', 'knapp', 'vier', 'Prozent', 'entsprechen', 'der', 'Österreich', 'signifikanen', 'Anstieg', 'häuslich', 'Gewalt', 'führen', 'der', 'geben', 'Innenminister', 'Karl', 'Nehammer', 'Frauenministerin', 'Susanne', 'Raab', 'beide', 'ÖVP', 'Montag', 'bekennen', 'der', 'verhängt', 'Betretungsverbote', 'demnach', '886', 'Februar', 'April', 'erhöhen', 'in', 'Juli', 'August', 'September', 'bisher', '507', 'der', 'meister', 'Alter', '15', '40', 'Jahr', 'weisen', 'Krankheit', 'Antikörper', 'der', 'gehen', 'reichenau', 'Rax', 'durchgeführen', 'Erhebung', 'hervor', 'der', 'überraschend', 'decken', 'mild', 'Verlauf', 'weniger', 'Antikörper', 'bilden', 'erklären', 'niederösterreichisch', 'Landessanitätsdirektorin', 'Irmgard', 'Lechner', 'der', 'Regierungsberater', 'Epidemiologe', 'Roman', 'prymula', 'neu', 'Gesundheitsminister', 'Tschechien', 'Präsident', 'Miloš', 'Zeman', 'prymula', 'Montagnachmittag', 'ernennen', 'Dienstag', 'parteilos', 'Nachfolger', 'zurückgetretenen', 'Adam', 'Vojtěch', 'anloben', 'sagen', 'Ministerpräsident', 'Andrej', 'Babiš', 'Montag', 'Nachrichtenagentur', 'CTK', 'München', 'verschärfen', 'ab', 'Donnerstag', 'dürfen', 'öffentlich', 'Raum', 'fünf', 'Mensch', 'treffen', 'für', 'privat', 'Fei', 'Geburtstag', 'Hochzeit', 'Beerdigung', 'gelten', 'künftig', 'Höchstgrenze', '25', 'Mensch', 'Geschlossen', 'Raum', '50', 'Mensch', 'treffen', 'draußen', 'außerdem', 'ordnen', 'Stadt', 'Maskenpflicht', 'einzeln', 'stark', 'besuchen', 'Ort', 'Marienplatz', 'Viktualienmarkt', 'Gesundheitsminister', 'Rudolf', 'Anschober', 'grüne', 'zeigen', 'Sonntagabend', 'in', 'Zentrum', 'zuversichtlich', 'zweiter', 'verhindern', 'der', 'Regierung', 'sein', 'professionell', 'schwierig', 'Situation', 'Herbst', 'vorbereiten', 'an', '11', 'Oktober', 'finden', 'Wien', 'Bezirksvertretungswahl', 'statt', 'an', 'Tag', 'Wahllokal', '7', '17', 'Uhr', 'öffnen', 'dabei', 'gelten', 'etwa', 'Maskenpflicht', 'Wähler', 'Wählerin', 'bitten', 'eigen', 'Kugelschreiber', 'ankreuzen', 'mitnehmen', 'heute', 'Österreich', 'weit', 'Einschränkung', 'Kraft', 'treten', 'ein', 'gelten', 'grundsätzlich', 'sozial', 'Aktivität', 'Gruppe', 'Geschlossen', 'Raum', 'stattfinden', 'der', 'Sperrstunde', 'generell', '1', 'Uhr', 'festlegen', 'Gastronomie', 'sowie', 'Geschlossen', 'Veranstaltung', 'Hochzeit', 'Festivität', 'ebenso', 'maximal', 'zehn', 'Person', 'privat', 'angemieteten', 'Club', 'Lokalitäto', 'red', 'Foto', 'Gambarini', 'Foto', 'Foeger', 'Foto', 'WACHEFoto', 'imago', 'Hoogte', 'Foto', 'ALESSANDRO', 'DELLA', 'vALLEFoto', 'GUEZFoto', 'SCHLAGERFoto', 'SCHLAGERFoto', 'gubisch', 'Foto', 'PFARRHOFERFoto', 'Imago', 'Foto', 'SCHLAGERFoto', 'FOHRINGERFoto', 'Foeger', 'Foto', 'GINDLFoto', 'Hoppe', 'Foto', 'Dapd', 'Sebastian', 'Widmann', 'Foto', 'APA', 'Hans', 'Punz', '|', 'Test', 'Arztpraxis', 'gesetzlich', 'verankern', '563']
# ['Attacke', 'Streit', 'Maskenpflicht', 'sorgen', 'deutsch', 'werden', 'Tankstellenkassier', 'erschießen', 'nachdem', 'Maskenpflicht', 'aufmerksam', 'machen', 'der', 'verdächtige', 'Blume', 'Kerze', 'Tankstelle', 'deutsch', 'erinnern', 'daran', 'Samstagabend', 'ereignen', 'ein', 'deutsche', 'geben', 'Oberstaatsanwaltschaft', 'Montag', 'bekennen', 'erschoss', 'Tankwart', 'zweimal', 'Maskenpflicht', 'aufmerksam', 'machen', 'nachdem', 'Großfahndung', 'schützen', 'erfolglos', 'bleiben', 'erscheinen', 'Sonntagfrüh', 'Polizei', 'dort', 'schildern', 'Beweggrund', 'er', 'lehnen', 'ab', 'Ecke', 'drängen', 'fühlen', 'Ausweg', 'sehen', 'Zeichen', 'setzen', 'der', 'Opfer', 'Student', 'nebenberuflich', 'arbeiten', 'scheinen', 'dabei', 'verantwortlich', 'Gesamtsituation', 'Regel', 'durchsetzen', 'sagen', 'Oberstaatsanwalt', 'Kai', 'Fuhrmann', 'deshalb', 'Tankstellenkassier', 'Revolver', 'gezielt', 'vorn', 'Kopf', 'schießen', 'kein', 'Waffenschein', 'der', 'mutmaßlich', 'Tatwaffe', 'sowie', 'weit', 'Waffe', 'Munition', 'werden', 'Wohnung', 'verdächtige', 'sicherstellen', 'wie', 'bekommen', 'unklar', 'Waffenschein', 'besitzen', 'der', 'verdächtige', 'zuvor', 'nie', 'polizeilich', 'auffallen', 'befinden', 'Untersuchungshaft', 'der', 'Ermittler', 'erhoffen', 'Auswertung', 'Handys', 'Mann', 'neu', 'Detail', 'Beispielsweise', 'gelten', 'klären', 'ja', 'Gruppierung', 'aktiv', 'der', 'entsetzen', 'Fall', 'groß', 'der', 'ganz', 'unfassbar', 'schrecklich', 'Tat', 'passieren', 'sagen', 'Oberbürgermeister', 'Frank', 'Frühauf', 'CDU', 'auch', 'Bundesregierung', 'melden', 'Wort', 'der', 'Radikalisierung', 'gewaltbereit', 'Rechtsstaat', 'Mittel', 'entgegenstellen', 'sagen', 'Justizministerin', 'Christine', 'Lambrecht', 'SPD', 'und', 'Annalena', 'Baerbock', 'twitteren', 'der', 'Radikalisierung', 'Querdenkermilieus', 'bereiten', 'groß', 'Sorge', 'ksh', 'Blume', 'Kerze', 'Tankstelle', 'deutsch', 'Kassier', 'Samstagabend', 'erschießen', 'werden', 'Foto', 'Weiss', '|', 'tödliche', 'Attacke', 'Streit', 'Maskenpflicht', 'sorgen', 'entsetzen']
# ['Aufruf', 'Polizei', 'kündigen', 'Kontrolle', 'Supermärkt', 'Freitag', 'Maskenfrei', 'einkaufen', 'gehen', 'der', 'betroffener', 'Handelskett', 'Exekutive', 'Kontakt', 'Wien', 'Maskengegner', 'sozial', 'Netzwerke', 'Aufruf', 'starten', 'Freitag', 'Österreichweit', 'Supermarktfilialen', 'Maskenfrei', 'einkaufen', 'gehen', 'der', 'Bundesamt', 'Verfassungsschutz', 'Terrorismusbekämpfung', 'BVT', 'Ermittlung', 'rund', 'Gruppierung', 'aufnehmen', 'Bezug', 'Organisation', 'extremistisch', 'Gruppe', 'ausschließen', 'der', 'Polizei', 'kündigen', 'Kontrolle', 'der', 'betroffener', 'Handelskett', 'Exekutive', 'Kontakt', 'der', 'Aufruf', 'werden', 'Telegram', 'verbreiten', 'zu', 'angegeben', 'Zeit', 'bestimmt', 'Filiale', 'mehrere', 'Handelskett', 'Bundesland', 'Gemüseabteilung', 'Maske', 'abnehmen', 'in', 'Supermärkt', 'gelten', 'laut', 'derzeitig', 'Verordnung', 'Mindestabstand', 'zwei', 'Meter', 'außerdem', 'tragen', 'der', 'Verweigerer', 'sollen', 'möglich', 'friedlich', 'entgegennehmen', 'bei', 'nächster', 'mal', 'teilnehmen', 'Punktuelle', 'Kontrolle', 'möglich', 'Dutzendfach', 'werden', 'Appell', 'bereits', 'Sicherheitsbehörde', 'melden', 'der', 'Polizei', 'kündigen', 'Streifendienst', 'besonders', 'darauf', 'achten', 'punktuell', 'Kontrolle', 'kommen', 'heißen', 'Innenministerium', 'der', 'Beamter', 'dialogorientieren', 'vorgehen', 'Anlassfall', 'Sanktion', 'setzen', 'erst', 'Anfang', 'Februar', 'werden', 'Strafe', 'Verstoß', 'verschärfen', 'bei', 'Missachtung', 'Mindestabstands', 'Polizei', 'Organstrafmandat', 'ausstellen', '90', 'Euro', 'dafür', 'fällig', 'außerdem', 'Anzeige', 'erstatten', 'APA', 'der', 'Polizei', 'kündigen', 'Streifendienst', 'besonders', 'Einhaltung', 'Maskenpflicht', 'achten', 'Foto', 'NEUBAUER', '|', 'nach', 'Aufruf', 'Polizei', 'kündigen', 'Kontrolle', 'Supermärkt']
# ['Botschafter', 'hoffen', 'partiell', 'Reisewarnung', 'Schulstart', 'halb', 'Klasse', 'sagen', 'APA', 'Schnelligkeit', 'Wiener', 'Entscheidung', 'schockieren', 'laut', 'Bildungsminister', 'Faßmann', 'künftig', 'Schulunterricht', 'freie', 'stattfinden', 'der', 'Wichtigste', 'Kürze', 'um', 'Mitternacht', 'Reisewarnung', 'Kroatien', 'Kraft', 'treten', 'Einreisende', 'Kroatien', 'müssen', 'negativ', 'vorlegen', 'binnen', '48', 'Stunde', 'Österreich', 'testen', 'lassen', 'Grenzkontrolle', 'werden', 'bereits', 'verstärken', 'lange', 'Wartezeit', 'Folge', 'der', 'Botschafter', 'Land', 'Österreich', 'Daniel', 'Gluncic', 'zeigen', 'APA', 'Geschwindigkeit', 'Entscheidung', 'irritieren', 'er', 'hoffen', 'Rücknahme', 'Pauschale', 'Warnung', 'schlagen', 'stattdessen', 'regional', 'Einschätzung', 'Gesundheitsminister', 'Rudolf', 'Anschober', 'grüne', 'trotz', 'Reisewarnung', 'Testung', 'Grenze', 'für', 'letzter', 'Tag', 'Kroatien', 'zurückkehren', 'gelten', 'verpflichtenden', 'Quarantan', 'Anschober', 'bitten', 'Vorsicht', 'Bildungsminister', 'Heinz', 'Faßmann', 'ÖVP', 'kündigen', 'ZiB', '2', 'erster', 'Eckpunkt', 'Schulöffnung', 'Herbst', 'so', 'flächendeckend', 'Schulschließung', 'Maskenpflicht', 'Unterricht', 'geben', 'der', 'erst', 'ab', 'ampelfarbe', 'gelb', 'Eingangsbereich', 'tragen', 'bei', 'Pressekonferenz', 'Montag', 'fügen', 'hinzu', 'häufig', 'lüften', 'Unterricht', 'freie', 'stattfinden', 'Durchmischung', 'Klasse', 'vermeiden', 'ein', 'erneut', 'Umstelle', 'Heimunterricht', 'regional', 'Zunahme', 'Österreich', 'Schule', 'erst', 'ab', 'rote', 'geben', 'für', 'Schüler', 'Sekundarstufe', 'II', 'ab', 'rund', '14', 'Jahr', 'schon', 'früh', 'Realität', 'man', 'brauchen', 'allerdings', 'klar', 'Definition', 'ab', 'wann', 'Ampelfarbe', 'springen', 'sagen', 'Faßmann', 'unser', 'Ambition', 'ampelfarbe', 'anpassen', 'der', 'deutsch', 'Gesundheitsminister', 'Jens', 'Spahn', 'CDU', 'warnen', 'Zusammenhang', 'erneut', 'steigend', 'Deutschland', 'Feierlichkeit', 'er', 'wollen', 'Bundesland', 'Grenze', 'Veranstaltungsgröß', 'prüfen', 'Neuseeland', 'verschieben', '19', 'September', 'geplant', 'Parlamentswahl', 'vier', 'Woche', 'Grund', 'Anfang', 'vergangen', 'Woche', 'registrieren', 'werden', '100', 'Tag', 'neu', 'Fall', 'weil', 'immer', 'mehr', 'jugendliche', 'Coronavirus', 'infizier', 'Italien', 'Schließung', 'Diskothek', 'Stranddisko', 'beschließen', 'der', 'Maßnahme', 'gelten', 'heute', 'Montag', '7', 'September', 'red', 'Foto', 'APA', 'Helmut', 'Fohringer', 'Foto', 'APA', 'EXPA', 'Johann', 'Groder', '|', 'kroatisch', 'Botschafter', 'hoffen', 'partiell', 'Reisewarnung', 'Schulstart', 'halb', 'Klasse', 'Schichtbetrieb']
# ['Bundesland', 'Nachtgastronomie', 'Großevent', 'gelten', 'bald', 'fünf', 'Bundesland', 'auch', 'werden', 'teils', 'nachgeschärfen', 'der', 'Mehrheit', 'Bundesland', 'Bund', 'erlassenen', 'Maßnahme', 'Bekämpfung', 'bereits', 'individuell', 'verschärfen', 'Verschärfung', 'ankündigen', 'bundesweit', 'vorgeben', 'Mindestmaß', 'Vorschrift', 'einhalten', 'mittlerweile', 'sechs', 'Land', 'eigenständig', 'weitergehend', 'Regel', 'etablieren', 'zuletzt', 'kündigen', 'Niederösterreich', 'Samstag', 'Verschärfung', 'zuvor', 'Freitag', 'Tirol', 'Oberösterreich', 'Kärnten', 'weit', 'Maßnahme', 'beschließen', 'dieser', 'Verschärfung', 'betreffen', 'Eintrittsregel', 'Nachgastronomie', 'Großevent', 'wer', 'künftig', 'Club', 'tanzen', 'Veranstaltung', 'mehr', '500', 'Person', 'besuchen', 'entweder', 'impfen', 'genesen', 'ein', 'rein', 'Nachweis', 'mittels', 'negativ', 'Coronatest', 'reichen', 'Nachtgastronomie', 'Großevent', 'mehr', 'in', 'Niederösterreich', 'Tirol', 'Steiermark', 'Oberösterreich', 'gelten', 'Verschärfung', 'ab', '8', 'November', 'Kärnten', 'bereits', 'ab', '4', 'November', 'in', 'Wien', 'gelten', 'bereits', 'seit', '1', 'Oktober', 'in', 'restlich', 'Bundesland', 'Burgenland', 'Salzburg', 'Vorarlberg', 'reichen', 'Nachtgastronomie', 'Großevent', 'Nachweis', 'negativ', 'alt', '72', 'Stunde', 'Verschärfte', 'bereits', 'seit', 'Freitag', 'gelten', 'Oberösterreich', 'verschärfen', 'sie', 'umfassen', 'gesamt', 'Handel', 'sowie', 'Kultureinrichtung', 'der', 'gelten', 'etwa', 'Museum', 'Bibliothek', 'in', 'Kino', 'Theater', 'sowie', 'körpernah', 'Dienstleister', 'bestehen', 'Maskenpflicht', 'vorlegen', 'Niederösterreich', 'Tirol', 'Steiermark', 'ziehen', 'Maßnahme', 'ab', '8', 'November', 'Kärnten', 'bereits', 'ab', '4', 'November', 'in', 'Salzburg', 'Wien', 'geben', 'bereits', 'verschärfen', 'Handel', 'diverser', 'Kulturbetriebe', 'in', 'Salzburg', 'gelten', 'Pflicht', 'körpernah', 'Dienstleistung', 'Ausreisekontrolle', 'zusätzlich', 'bestehend', 'Maßnahme', 'geben', 'aktuell', 'elf', 'österreichisch', 'Bezirk', 'bzw', 'Gemeinde', 'Ausreisekontrolle', 'Übersicht', 'Öamtc', 'der', 'bedeuten', 'wer', 'entsprechend', 'Gemeindegebiet', 'verlassen', 'möchten', 'impfen', 'testen', 'genesen', 'in', 'Salzburg', 'betreffen', 'Regel', 'Gemeinde', 'Koloman', 'Adnet', 'für', 'Person', 'ab', '12', 'Jahr', 'Ausreis', 'Impfzertifikat', 'Genesungsnachweis', 'gültig', 'vorweisen', 'in', 'Niederösterreich', 'Bezirk', 'Lilienfeld', 'Amstette', 'Melk', 'Scheibbs', 'Hochrisikogebiet', 'deklarieren', 'wer', 'Bezirk', 'verlassen', 'möchten', 'brauchen', 'gültig', 'anders', 'betroffener', 'Salzburger', 'Gemeinde', 'gelten', 'negativ', 'Antigentest', 'alt', '24', 'Stunde', 'in', 'Oberösterreich', 'mittlerweile', 'drei', 'Bezirk', 'Ausreis', 'einführen', 'nach', 'Braunau', 'Freistadt', 'geben', 'Bezirk', 'Gmunden', 'seit', 'Samstag', 'Ausreisekontrolle', 'als', 'Nachweis', 'gelten', 'negativ', 'alt', '72', 'Stunde', 'dürfen', 'negativ', 'alt', '24', 'Stunde', 'neu', 'bundesweit', 'Verordnung', 'ab', '1', 'November', 'ab', '1', 'November', 'treten', 'planmäßig', 'neu', 'Maßnahme', 'Eindämmung', 'Coronapandemie', 'Kraft', 'ganz', 'Österreich', 'so', 'etwa', 'Geschäft', 'täglich', 'Bedarf', 'einführen', 'in', 'Bereich', 'der', 'bereits', 'einzelner', 'Bundesland', 'streng', 'Regel', 'gelten', 'bleiben', 'erhalten', 'ein', 'Überblick', 'finden', 'sie', 'Seite', 'Gesundheitsministerium', 'außerdem', 'treten', 'Montag', 'Arbeitsplatz', 'Kraft', 'freilich', 'können', 'Regel', 'schon', 'bald', 'ändern', 'Gesundheitsminister', 'Wolfgang', 'Mückstein', 'grüne', 'geben', 'Samstag', 'bekennen', 'wahrscheinlich', 'Ende', 'Nächster', 'Woche', 'Anfang', 'übernächst', 'Woche', 'bereits', '400', 'Intensivbett', 'ausgelasten', 'sein', 'der', 'bedeuten', 'Stufe', 'drei', 'Stufenplan', 'erreichen', 'somit', 'sein', 'Bereich', 'derzeit', 'Antigentest', 'Nachweis', 'erlauben', 'negativ', 'gültig', 'Lalo', 'APA', 'Updat', 'Uhr', 'Verschärfung', 'Niederösterreich', 'ergänzen', 'zu' ...
# ['Clemens', 'Auer', 'italienisch', 'spanisch', 'Verhältnis', 'vermeiden', 'mehr', 'Testung', 'Clemens', 'Auer', 'Gesundheitsministerium', 'Chat', 'Gast', 'seit', 'Mittwoch', 'Österreich', 'Supermärkt', 'Gesichtsmask', 'verteilen', 'ein', 'Maßnahme', 'Clemens', 'Martin', 'Auer', 'Sonderbeauftragter', 'Gesundheitsministerium', 'Rolle', 'Berater', 'Gesundheitsminister', 'Rudolf', 'Anschober', 'grüne', 'begrüßen', 'Sinn', 'Zweck', 'Übung', 'ja', 'Person', 'potenziell', 'Ausstoß', 'Tröpfche', 'Nasenbereich', 'minimieren', 'sodass', 'Tröpfche', 'Person', 'gelangen', 'beantworten', 'entsprechend', 'Frage', 'User', 'Auer', 'werden', 'Mittwoch', 'Kritik', 'konfrontieren', 'etwa', 'Frage', 'warum', 'wenig', 'testen', 'wir', 'Österreich', 'heutig', 'Tag', 'Test', 'durchführen', 'wobei', 'international', 'Vergleich', 'oberer', 'Drittel', 'Land', 'liegen', 'man', 'teste', 'derzeit', 'Person', 'Symptom', 'beginnen', 'repräsentativ', 'Testung', 'Bevölkerung', 'einzelner', 'Berufsgruppe', 'vornehmen', 'der', 'Test', 'billig', 'eingesetzt', 'Euro', 'gut', 'investieren', 'Klarheit', 'Entwicklung', 'Pandemie', 'bekommen', 'Auer', 'dass', 'anfangs', 'Ernst', 'genug', 'nehmen', 'werden', 'weisen', 'Experte', 'zurück', 'ich', 'lang', 'beruflich', 'Karriere', 'nie', 'erleben', 'zuständig', 'Gesundheitsbehörde', 'allermeister', 'Land', 'rasch', 'neu', 'aufgetretenes', 'Virus', 'reagieren', 'auch', 'Maßnahmenpaket', 'Regierung', 'verteidigen', 'Auer', 'es', 'sein', 'Ziel', 'Schule', 'Unternehmen', 'Monat', 'hinweg', 'schließen', 'halten', 'aber', 'müssen', 'Neuinfektionsrat', 'Beginn', 'Pandemie', 'flach', 'halten', 'stationär', 'Einrichtung', 'besonders', 'stark', 'erkrankter', 'ähnlich', 'dramatisch', 'Verhältnis', 'Italien', 'Spanien', 'kommen', 'kein', 'diktatorisch', 'Mittel', 'der', 'Entscheidungsfindung', 'Krisenstäbe', 'Erfolg', 'hoch', 'ethisch', 'Bewusstsein', 'Abwägung', 'richtig', 'falsch', 'Auer', 'man', 'schaffen', 'Maßnahme', 'setzen', 'diktatorisch', 'Mittel', 'greifen', 'müssen', 'der', 'Zusammenarbeit', 'Bundesland', 'bezeichnen', 'gelingen', 'ich', 'verantwortliche', 'gemeinsam', 'vorbildlich', 'Eventualität', 'vorbereiten', 'in', 'Sache', 'Entwicklung', 'Impfstoff', 'glauben', 'Auer', 'Geduld', 'Tag', 'legen', 'müssen', 'der', 'Weltgesundheitsorganisation', 'WHO', 'gehen', 'davon', 'Impfstoff', 'realistischerweis', 'Jahr', 'Verfügung', 'stehen', 'anders', 'verhalten', 'Medikament', 'solcher', 'Therapie', 'Impfstoffen', 'vorliegen', 'schließlich', 'geben', 'Auer', 'Entwarnung', 'Übertragung', 'Virus', 'Papier', 'Kartonagen', 'bzw', 'Essenszusteller', 'betreffen', 'es', 'Literatur', 'unbekannt', 'Virus', 'Kartonagen', 'weiterverbreiten', 'sie', 'daher', 'unbedenklich', 'ihr', 'Pizzakarton', 'angreifen', 'wenn', 'sie', 'sicher', 'waschen', 'sie', 'gründlich', 'Hand', 'Rosa', 'Foto', '|', 'Sonderbeauftragter', 'Clemens', 'Auer', 'italienisch', 'spanisch', 'Verhältnis', 'vermeiden']
# ['Coronavirus', 'Geringe', 'Testbeteiligung', 'Wien', 'zeichnen', 'ab', 'USA', 'starten', 'ab', 'Montag', 'österreichisch', 'Regierung', 'denken', 'offenbar', 'Anreizsystem', 'Mensch', 'Teilnahme', 'Massentest', 'bewegen', 'der', 'wichtig', 'Tag', 'der', 'Wichtigste', 'Kürze', 'in', 'Österreich', 'vergangen', '24', 'Stunde', 'Neuinfektion', 'Virus', 'registrieren', 'werden', 'der', 'Zahl', 'Todesfall', 'steigen', '126', 'bei', 'Übermittlung', 'kommen', 'Samstag', 'Verzögerung', 'der', 'System', 'laut', 'Meldung', 'wegen', 'vorerst', 'heruntergefahren', 'in', 'Deutschland', 'zeichnen', 'Vorgespräch', 'Bund', 'Land', 'offenbar', 'hart', 'Lockdown', 'ab', 'Mittwoch', 'ab', 'Wien', 'gehen', 'Sonntag', 'letzter', 'Tag', 'Massentest', 'bisher', 'dürfen', 'Beteiligung', 'zehn', 'Prozent', 'liegen', 'laut', 'Medienbericht', 'überlegen', 'Regierung', 'Anreizsystem', 'Massentest', 'schaffen', 'Jänner', 'Teilnehmerzahl', 'steigern', 'der', 'Regierung', 'Bundesland', 'neu', 'Regel', 'Weihnachtsfeiertage', 'Silvester', 'verständigen', 'zudem', 'kommen', 'Maskenpflicht', 'stark', 'frequentieren', 'Ort', 'freie', 'Arbeitsplatz', 'Abstandsregel', 'einhalten', 'von', '10', 'Jänner', 'zweiter', 'Runde', 'Massentest', 'vorsehen', 'Wien', '17', 'Jänner', 'für', 'Berufsgruppe', 'Lehrer', 'körpernah', 'Dienstleister', 'verpflichtenden', 'Test', 'geben', 'der', 'Reproduktionszahl', 'Österreich', 'Stand', 'Freitag', 'leicht', 'sinken', 'vergangene', 'Woche', 'liegen', 'in', 'USA', 'ab', 'Montag', 'Impfung', 'beginnen', 'der', 'FDA', 'Impfstoff', 'Biontech', 'Notfallzulassung', 'erteilen', 'Deutschland', 'melden', 'mehr', 'Neuinfektion', 'red', 'mehr', 'Thema', 'wie', 'Symptom', 'Grippe', 'grippal', 'Infekt', 'unterscheiden', 'der', 'erzählen', 'betroffener', 'erzählen', 'so', 'überstehen', 'Foto', 'Scheriau', 'Foto', 'Oczeret', 'Foto', 'APA', 'Hanz', 'Punkz', 'Foto', 'JAEGERFoto', 'OCZERETFoto', 'AFP', 'THOMAS', 'SAMSONFoto', 'AFP', 'Go', 'Nakamura', 'Foto', 'Photo', 'Foto', 'SCHERIAUFoto', 'APA', 'AFP', 'Tobias', 'schwarz', 'Foto', 'STENNINGFoto', 'FOHRINGERFoto', 'reutersFoto', 'Humphrey', 'Foto', 'Lipinski', 'Foto', 'APA', 'BARBARA', 'GINDLFoto', 'APA', 'HERBERT', 'nEUBAUERFoto', 'nEUBAUERFoto', 'GINDL', '|', 'Geringe', 'Testbeteiligung', 'Wien', 'zeichnen', 'ab', 'USA', 'starten', 'ab', 'Montag', 'Impfung']
# ['Coronavirus', 'Gottesdienst', 'ab', 'Sonntag', 'möglich', 'Grenzpendler', 'brauchen', 'negativ', 'Montag', '90', 'Euro', 'Strafe', 'Nichteinhalten', 'Maskenpflicht', 'skigebieten', 'verstärken', 'Kontrolle', 'geben', 'der', 'Schule', 'stellen', 'weitgehend', 'Schichtbetrieb', 'der', 'Wichtigste', 'Kürze', 'in', 'Pressekonferenz', 'präsentieren', 'Regierung', 'Montagabend', 'Öffnungsschritt', 'ab', '8', 'Februar', 'sollen', 'Handel', 'Museum', 'Galerie', 'Zoos', 'aufsperren', 'es', 'Beschränkung', 'Kundenanzahl', 'geben', 'der', 'Schule', 'sollen', 'Semesterferie', 'Präsenzunterricht', 'zurückkehren', 'Volksschule', 'vollständig', 'Oberstufen', 'staffeln', 'Gruppe', 'Montag', 'Dienstag', 'Mittwoch', 'Donnerstag', 'der', 'Freitag', 'Tag', 'Distanzlernen', 'an', 'Präsenzunterricht', 'teilnehmen', 'wer', 'testen', 'lässen', 'körpernahe', 'Dienstleister', 'dürfen', 'öffnen', 'darunter', 'fallen', 'Beispiel', 'Friseur', 'koppeln', 'Eintrittstest', 'maximal', '48', 'Stunde', 'alt', 'dürfen', 'Gottesdienst', 'Einhaltung', 'Mindestabstand', 'ab', 'Sonntag', 'möglich', 'Ausgangsbeschränkung', 'bleiben', '20', '6', 'Uhr', 'bestehen', 'in', 'privat', 'Bereich', 'dürfen', 'ab', '8', 'Februar', 'zwei', 'Haushalt', 'treffen', 'Grenzpendler', 'müssen', 'registrieren', 'lassen', 'negativ', 'Test', 'vorweisen', 'der', 'Strafe', 'Nichteinhalten', 'Maskenpflicht', '90', 'Euro', 'erhöhen', 'kündigen', 'Gesundheitsminister', 'Rudolf', 'Anschober', 'grüne', 'Dienstag', 'Morgenjournal', 'Bundeskanzler', 'Sebastian', 'kurz', 'ÖVP', 'betonen', 'Lockerung', 'Entwarnung', 'sein', 'bei', 'exponentiell', 'Wachstum', 'müssten', 'Lockerung', 'zurücknehmen', 'an', '15', 'Februar', 'weit', 'Öffnungsschritt', 'beraten', 'Beispiel', 'Tourismus', 'Sport', 'Kulturbereich', 'an', 'Dienstag', 'werden', 'Österreich', 'melden', 'der', 'russisch', 'Sputnik', 'V', 'weisen', 'laut', 'Wirksamkeit', 'Prozent', 'Biontech', 'Produktion', '50', 'Prozent', 'steigern', 'der', 'EU', 'dadurch', '75', 'Million', 'mehr', 'Impfdose', 'zweiter', 'Quartal', 'erhalten', 'was', 'Debatte', 'Verzögerung', 'Impfstoff', 'anbelangen', 'weisen', 'Kritik', 'zurück', 'fast', 'Plan', 'red', 'mehr', 'Thema', 'wie', 'Symptom', 'Grippe', 'grippal', 'Infekt', 'unterscheiden', 'der', 'erzählen', 'betroffener', 'erzählen', 'so', 'überstehen', 'warum', 'Krisenstab', 'Ages', 'unterschiedlich', 'berechnen', 'Foto', 'PUNZFoto', 'Robert', 'JägerFoto', 'PUNZFoto', 'AP', 'Wilfredo', 'Lee', 'Foto', 'PETERFoto', 'APA', 'GEORG', 'HOCHMUTHFoto', 'AFP', 'JONATHAN', 'NACKSTRANDFoto', 'APA', 'HERBERT', 'nEUBAUERFoto', 'nEUBAUERFoto', 'APA', 'Jan', 'Woitas', 'Foto', 'APA', 'HERBERT', 'PFARRHOFERFoto', 'APA', 'GEORG', 'HOCHMUTHFoto', 'AFP', 'PAUL', 'FAITHFoto', 'REUTERS', 'DADO', 'RUVICFoto', 'EPAFoto', 'APA', 'EXPA', 'Johann', 'Groder', 'Foto', 'PUNZ', '|', 'Gottesdienst', 'ab', 'Sonntag', 'möglich', 'Grenzpendler', 'brauchen', 'negativ']
# ['Coronavirus', 'Handel', 'schließen', 'Ostern', 'danach', 'Zugangstest', 'Schule', 'Fernunterricht', 'Gründonnerstag', 'Osterdienstag', 'Handel', 'schließen', 'in', 'Zeit', 'gelten', 'Ausgangsbeschränkung', '0', '24', 'Uhr', 'der', 'Wichtigste', 'Kürze', 'an', 'Mittwoch', 'gehen', 'Verhandlung', 'Ostregion', 'streng', 'Ende', 'folgende', 'Maßnahme', 'werden', 'Wien', 'Niederösterreich', 'Burgenland', 'vereinbaren', 'der', 'Handel', 'Ausnahme', 'Gut', 'täglich', 'Bedarf', 'körpernah', 'Dienstleister', 'schließen', 'ab', 'Handel', 'Zugangstest', 'notwendig', 'in', 'Innenräum', 'gelten', 'mehr', 'Person', 'anwesend', 'dieser', 'gelten', 'Menschenansammlung', 'freie', 'in', 'Schule', 'gelten', 'Woche', 'Ostern', 'danach', 'Schrittweise', 'Schule', 'kommen', 'Ausgangsbeschränkung', 'rund', 'Weihnachten', 'Ausgangssperre', 'Uhr', 'üblich', 'Ausnahme', 'mehr', 'Kontrolle', 'Pendler', 'Risikogebiet', 'zwei', 'Test', 'pro', 'Woche', 'stark', 'Kontrolle', 'Grenze', 'Anschober', 'Ostösterreich', 'Pilotregion', 'leicht', 'Bundesland', 'kommen', 'an', 'Mittwoch', 'werden', 'Neuinfektion', 'Österreich', 'registrieren', 'Deutschland', 'nehmen', 'Vorhaben', 'zurück', 'Land', 'Ostern', 'Ruhetage', 'Gründonnerstag', 'Samstag', 'Lockdown', 'schicken', 'dieser', 'kündigen', 'Angela', 'Merkel', 'Mittwoch', 'der', 'Test', 'Ausreis', 'Schwaz', 'Tirol', 'Verbreitung', 'Virusvariant', 'verhindern', 'sollen', 'bleiben', '1', 'April', 'aufrecht', 'hinzu', 'kommen', 'Verschärfung', 'Vorarlberger', 'Laiblachtal', 'niederösterreichisch', 'Bezirk', 'Wiener', 'neunkirchen', 'ab', 'Donnerstag', 'Ausreisetest', 'benötigen', 'an', 'Mittwoch', 'geben', 'Krisenstab', 'bekennen', '176', 'Wien', 'intensivmedizinisch', 'Betreuung', 'brauchen', 'vieler', 'nie', 'zuvor', 'rund', 'Million', 'Impfung', 'werden', 'bisher', 'Österreich', 'durchführen', 'Mensch', 'bereits', 'voll', 'immunisieren', 'vor', 'Hintergrund', 'Streit', 'EU', 'Astra', 'Zeneca', 'Fund', '29', 'Million', 'Dose', 'abfüllstätte', 'Italien', 'Verwirrung', 'sorgen', 'in', 'Deutschland', 'Bundeskanzlerin', 'Angela', 'Merkel', 'Land', 'verabreden', 'Ruhetagsregel', 'Ostertage', 'zurücknehmen', 'entstanden', 'Verunsicherung', 'entschuldigen', 'red', 'mehr', 'Thema', 'wie', 'Symptom', 'Grippe', 'grippal', 'Infekt', 'unterscheiden', 'der', 'erzählen', 'Foto', 'Hubatka', 'via', 'FOHRINGER', '|', 'Handel', 'schließen', 'Ostern', 'danach', 'Zugangstest', 'Schule', 'Fernunterricht', 'Ferien']
# ['Coronavirus', 'Impfbeginn', 'Österreich', '27', 'Dezember', 'neun', 'Uhr', 'Köstinger', 'Staatssekretärin', 'Mayer', 'kündigen', '300', 'Million', 'Euro', 'dotiert', 'Schutzschirm', 'Veranstalter', 'der', 'Überblick', 'der', 'Wichtigste', 'Kürze', 'Bundeskanzler', 'Sebastian', 'kurz', 'ÖVP', 'Gesundheitsminister', 'Rudolf', 'Anschober', 'grüne', 'österreichweiten', 'Impfstart', 'informieren', 'wie', 'planen', 'beginnen', 'Impfung', '27', 'Dezember', 'neun', 'Uhr', 'der', 'erster', 'Impfdose', 'gehen', 'Risikogruppe', 'der', 'breit', 'Bevölkerung', 'Monat', 'dulden', 'müssen', 'der', 'Verfassungsgerichtshof', 'erklären', 'Klassenteilung', 'Maskenpflicht', 'Frühjahr', 'gesetzeswidrig', 'der', 'Entscheidungsgrundlag', 'Verordnung', 'Bildungsministerium', 'Höchstgericht', 'erkennbar', 'der', 'entsprechend', 'Gesetz', 'bereits', 'außer', 'Kraft', 'Tourismusministerin', 'Elisabeth', 'Köstinger', 'ÖVP', 'präsentieren', 'gemeinsam', 'Kulturstaatssekretärin', 'Andrea', 'Mayer', 'grüne', 'finanziell', 'Schutzschirm', 'Veranstalter', 'es', '300', 'Million', 'Euro', 'Jahr', '2020', '2021', '2022', 'Verfügung', 'stellen', 'in', 'Österreich', 'werden', 'Mittwoch', 'innerhalb', 'vergangen', '24', 'Stunde', 'bekanntgeben', 'in', 'Teststraße', 'bei', 'Austria', 'Center', 'Wien', 'geben', 'weit', 'bis', '26', 'Dezember', 'zusätzlich', 'Termin', 'pro', 'Tag', 'möglich', 'red', 'mehr', 'Thema', 'wie', 'Symptom', 'Grippe', 'grippal', 'Infekt', 'unterscheiden', 'der', 'erzählen', 'betroffener', 'erzählen', 'so', 'überstehen', 'warum', 'Krisenstab', 'Ages', 'unterschiedlich', 'berechnen', 'Foto', 'AP', 'huh', 'Fil', 'Foto', 'NEUBAUER', '|', 'Impfbeginn', 'Österreich', '27', 'Dezember', 'neun', 'Uhr', 'Neuinfektion']
# ...
# ['Österreich', 'Intensivstation', 'Reproduktionsfaktor', 'kurz', 'eigen', 'Angabe', 'früh', 'verschärfen', 'Morgen', 'treten', 'Kraft', 'der', 'Überblick', 'der', 'Wichtigste', 'Kürze', 'der', 'Zahl', 'aktiv', 'Österreich', 'Sonntag', 'überschreiten', 'der', 'Reproduktionsfaktor', 'liegen', 'aktuell', 'laut', 'Angabe', 'Gesundheitsministerium', 'Stand', 'Uhr', 'Mensch', 'aktiv', 'infizieren', 'binnen', '24', 'Stunde', 'kommen', '621', 'Neuinfektion', 'hinzu', 'alle', 'Zahl', 'finden', 'sie', 'groß', 'Überblick', '68', 'Österreich', 'liegen', 'derzeit', 'Intensivstation', 'davon', '38', 'Wien', 'für', 'Spital', 'behandeln', 'müssen', 'stehen', '400', 'Normalbett', '150', 'Intensivstation', 'Verfügung', 'Anschober', 'verkünden', 'Woche', 'mehr', 'Testung', 'Rekordzahl', 'erreichen', 'werden', 'Bundeskanzler', 'Sebastian', 'kurz', 'ÖVP', 'laut', 'eigen', 'Aussage', 'schon', 'früh', 'neuerlich', 'Ansteige', 'Infektion', 'reagieren', 'der', 'sein', 'alleinig', 'Entscheidung', 'sagen', 'Österreich', 'der', 'Stadt', 'Wien', 'gemeinsam', 'Polizei', '26', 'Betrieb', 'Wiener', 'Clubszen', 'durchführen', 'Dutzend', 'Verstoß', 'werden', 'registrieren', 'ab', 'Montag', 'null', 'Uhr', 'verschärfen', 'private', 'Veranstaltung', 'Innenraum', 'beschränken', 'Maskenpflicht', 'ausweiten', 'seit', 'Freitagabend', 'Detail', 'neu', 'Verordnung', 'bekennen', 'weltweit', 'inzwischen', 'mehr', 'Million', 'Mensch', 'Coronavirus', 'infizieren', 'fast', 'Million', 'sterben', 'der', 'USA', 'bleiben', 'rund', 'Million', 'bestätigen', 'Fall', 'fast', 'tote', 'stark', 'betroffen', 'Land', 'folgen', 'Indien', 'Brasilien', 'red', 'Foto', 'imago', 'Hoogte', 'Foto', 'ALESSANDRO', 'DELLA', 'vALLEFoto', 'GUEZFoto', 'SCHLAGERFoto', 'SCHLAGERFoto', 'gubisch', 'Foto', 'PFARRHOFERFoto', 'Imago', 'Foto', 'SCHLAGERFoto', 'FOHRINGERFoto', 'Foeger', 'Foto', 'GINDLFoto', 'Hoppe', 'Foto', 'Dapd', 'Sebastian', 'Widmann', 'Foto', 'APA', 'Hans', 'Punz', '|', '68', 'Österreich', 'Intensivstation', 'Reproduktionsfaktor']
# ['Österreich', 'bleiben', 'Donnerstagabend', 'Offenhalten', 'Schule', 'aussprechen', 'Wien', 'der', 'Gesundheitsministerium', 'Sitzung', 'Donnerstagnachmittag', 'gleich', 'Einschätzung', 'Vorwoche', 'kommen', 'der', 'Infektionsrisiko', 'gesamt', 'Land', 'hoch', 'bleiben', 'werden', 'Ampel', 'Vorwoche', 'Bezirk', 'Bundesland', 'gesamt', 'Land', 'rote', 'stellen', 'wie', 'Oberösterreichischen', 'Nachricht', 'berichten', 'werden', 'weit', 'Maßnahme', 'eingemahnen', 'Zusammenbruch', 'Gesundheitssystem', 'verhindern', 'laut', 'OÖN', 'Kommission', 'angesichts', 'dramatisch', 'Österreich', 'Politik', 'geraten', 'möglichst', 'zeitnah', 'zusätzlich', 'Maßnahme', 'ergreifen', 'Zusammenbruch', 'Gesundheitssystem', 'verhindern', 'Konkreter', 'werden', 'Empfehlung', 'verweisen', 'werden', 'ausgangsregeln', 'Betretungsverbote', 'dieser', 'dürfen', 'wohl', 'bedeuten', 'Sicht', 'Experte', 'Ausgangsbeschränkung', 'Handel', 'Dienstleistung', 'öffentlich', 'Ort', 'öffentlich', 'Verkehr', 'nachgeschärfen', 'der', 'bereits', 'gesetzt', 'Gelindere', 'Maßnahme', 'Eindämmung', 'Infektionsgeschehen', 'ausreichend', 'Wirkung', 'entfalten', 'zitieren', 'Zeitung', 'Beschluss', '17', '19', 'Kommissionsmitglied', 'haben', 'zustimmen', 'Vertreter', 'Kärnten', 'Fachexpertin', 'enthalten', 'heißen', 'Kommission', 'offen', 'Schule', 'zudem', 'Ampelkommission', 'Donnerstagabend', 'Offenhalten', 'Schule', 'aussprechen', 'der', 'APA', 'Teilnehmerkreis', 'erfahren', 'der', 'Beschluss', 'fallen', 'demnach', 'einstimmig', 'lediglich', 'Bundeskanzleramt', 'enthalten', 'der', 'Empfehlung', 'Kindergärte', 'Volksschule', 'sowie', 'Sekundarstufe', '1', 'möglichst', 'lang', 'offenhalten', 'bleiben', 'aufrecht', 'heißen', 'Beschluss', 'bei', 'Betreuungseinrichtung', 'handeln', 'aktuell', 'Zahl', 'Agentur', 'Gesundheit', 'Ernährungssicherheit', 'Ages', 'Treiber', 'Infektionsgeschehen', 'der', 'Bildungsministerium', 'weit', 'Präventionsmaßnahme', 'empfehlen', 'Schulbetrieb', 'Gruppe', 'höherem', 'Infektionsgescheh', 'weiterhin', 'ermöglichen', 'es', 'sollen', 'Einsatz', 'kommen', 'Maskenpflicht', 'Schüler', 'Lehrer', 'Unterricht', 'Staffelung', 'Nutzung', 'groß', 'Raum', 'Sport', 'freie', 'APA', 'red', 'neu', 'Tweet', 'Foto', 'FOHRINGER', 'if', 'apaResc', 'Var', 'a', 'Var', 'add', 'Event', 'Listener', 'attachEvent', 't', 'n', '0', 'Window', 'e', 'attachEvent', 'Onmessage', 'Message', 'function', 'e', 'if', 'a', 'for', 'Var', 'a', 'n', 't', 'n', 'a', 'px', '1', 'apaResc', 'neu', 'HTML', 'Tag', '|', 'Österreich', 'bleiben', 'rot']
# ['ÖsterreichRekord', 'seit', 'Jahresbeginn', 'Neuinfektion', 'Zahl', 'liegen', 'deutlich', 'Schnitt', 'vergangen', 'sieben', 'Tag', '250', 'befinden', 'Intensivstation', 'Wien', 'mehr', 'Mittwoch', 'Österreich', 'melden', 'werden', 'über', 'neu', 'Fall', 'zuletzt', 'rund', 'elf', 'Monat', 'geben', 'außerdem', 'mussen', 'nunmehr', '250', 'Intensivstation', 'behandeln', 'sechs', 'mehr', 'Dienstag', 'Infizierte', 'müssen', 'Spitäler', 'behandeln', '89', 'mehr', 'Dienstag', 'seit', 'Vortag', 'werden', 'außerdem', 'zehn', 'weit', 'Todesfall', 'registrieren', 'Gesundheitsministerium', 'melden', 'genau', 'Neuinfektion', 'binnen', '24', 'Stunde', 'der', 'liegen', 'deutlich', 'Schnitt', 'vergangen', 'sieben', 'Tag', 'täglich', 'neu', 'Fall', 'mehr', 'Fall', 'werden', 'zuletzt', 'fast', 'genau', 'elf', 'Monat', 'melden', 'an', '29', 'November', '2020', 'Österreichweit', 'Neuinfektion', 'Wien', 'sehen', 'bestätigen', 'der', 'steigen', 'Mittwoch', 'Fall', 'Einwohner', 'Dienstag', 'an', 'Mittwoch', 'geben', 'Österreichweit', 'bestätigen', 'aktiv', 'Fall', 'mehr', 'Bregenz', 'Einwohner', 'in', 'Krankenhaus', 'liegen', 'bereits', 'Infizierte', 'innerhalb', 'Woche', 'geben', 'Plus', 'mehr', '30', 'Prozent', '250', 'schwerkrank', 'Intensivstation', 'betreuen', '32', 'Patient', 'mehr', 'Woche', 'der', 'bedeuten', 'Steigerung', 'knapp', '15', 'Prozent', 'vor', 'genau', 'Jahr', '27', 'Oktober', '2020', 'liegen', 'mehr', 'Infizierte', 'Spitäler', 'weniger', 'Intensivstation', 'der', 'Sprecher', 'Wiener', 'Gesundheitsstadtrat', 'Peter', 'Hacker', 'SPÖ', 'Mario', 'Dujaković', 'nehmen', 'Zahl', 'Anlass', 'Wiener', 'Weg', 'Hervorzuheb', 'Wien', 'Maßnahme', 'Dynamik', 'Entwicklung', 'herausnehmen', 'der', 'zeigen', 'Inzidenzen', 'nichtbeeinflussbaren', 'Naturphänomene', 'man', 'Steuer', 'anpacken', 'Dujaković', 'mit', 'Steiermark', 'nehmen', 'Bundesland', 'offenbar', 'Beispiel', 'Wien', 'an', 'Mittwoch', 'verkünden', 'Landeshauptmann', 'Hermann', 'Schützenhöfer', 'ÖVP', 'streng', 'Regel', 'Nachtgastro', 'sowie', 'Großevent', 'ab', '8', 'November', 'Zulassung', '2', 'G', 'impfen', 'Getetest', 'erlauben', 'dazu', 'kommen', 'Kundenbereich', 'Kulturevent', 'religiös', 'Zusammenkünft', 'beschäftigter', 'Besucher', 'Spitäler', 'Kuranstalt', 'Pflegeheime', 'unterliegen', 'künftig', 'genesen', 'impfen', 'in', 'Ordination', 'gelten', 'selbig', 'Personal', 'der', 'müssen', 'dabei', 'extern', 'Laboren', 'auswerten', 'somit', 'kommen', 'weiterhin', 'Test', 'Apotheke', 'Teststraße', 'Gurgeltest', 'Frage', 'sagen', 'Gesundheitslandesrätin', 'Juliane', 'ÖVP', 'bei', 'Pressegespräch', 'Graz', 'Nachfrage', 'der', 'Gültigkeitsdauer', 'bleiben', '72', 'Stunde', 'Impfbereitschaft', 'stocken', 'zudem', 'werden', 'seit', 'Dienstag', 'zehn', 'Todesfall', 'registrieren', 'in', 'vergangen', 'Woche', 'verstarben', '80', 'Mensch', 'insgesamt', 'seit', 'Ausbruch', 'Todesopfer', 'Österreich', 'fordern', 'pro', 'Einwohner', 'bereits', 'Mensch', 'Folge', 'Infektion', 'sterben', 'zu', 'Impfung', 'schwer', 'Verlauf', 'Großteils', 'verhindern', 'immer', 'weniger', 'Mensch', 'Österreich', 'bereit', 'insgesamt', 'laut', 'Datum', 'Mensch', 'bereits', 'zumindest', 'Teilimpfung', 'erhalten', 'der', 'Prozent', 'Bevölkerung', 'exakt', 'Person', 'somit', 'Prozent', 'Österreicher', 'bereits', 'vollständig', 'impfen', 'APA', 'red', 'gelten', 'exakt', 'Feststellungsmethode', 'Foto', 'FOEGERNeuer', 'Tweet', '|', 'Rekord', 'seit', 'Jahresbeginn', 'Neuinfektion', 'Österreich']
# ['ÖsterreichVirologin', 'Laer', 'brauchen', 'Million', 'Immunisiert', 'Gesamtschutz', 'Prozent', 'Immunisiert', 'fehlen', 'laut', 'Medizinerin', 'Österreich', 'entspannter', 'Umgang', 'impfen', 'mit', 'dreiwöchig', 'Sicherheitsphase', 'Montag', 'Oberösterreich', 'Salzburg', 'Tirol', 'Vorarlberg', 'Kärnten', 'Steiermark', 'rund', 'Kind', 'jugendliche', 'neu', 'Schuljahr', 'beginnen', 'in', 'Zeit', 'Teilnahme', 'Unterricht', 'drei', 'pro', 'Woche', 'durchführen', 'davon', 'außerhalb', 'Klasse', 'müssen', 'Schülerin', 'Schüler', 'Maske', 'tragen', 'der', 'Testregel', 'gelten', 'Lehrpersonal', 'für', 'rund', 'Kind', 'Bundesland', 'allererste', 'Schultag', 'sie', 'Eltern', 'Schule', 'begleiten', 'müssen', 'allerdings', 'vorlegen', 'ganz', 'Schulgebäude', 'Maske', 'aufhaben', 'in', 'Wien', 'Niederösterreich', 'Burgenland', 'Schuljahr', 'bereits', 'Woche', 'früh', 'beginnen', 'positiv', 'Fall', 'Osten', 'etwas', '500', 'positiv', 'lauten', 'Bilanz', 'ausgedehnt', 'Test', 'Schule', 'erster', 'Woche', 'Schulbeginn', 'Ostösterreich', 'wobei', 'bisherig', 'Öffnung', 'bisher', 'epidemiologisch', 'Gesamtgewicht', 'fallen', 'Komplexitätsforscher', 'Peter', 'Klimek', 'betonen', 'der', 'wirklich', 'Auswirkung', 'sehen', 'erst', 'nächster', 'paar', 'Woche', 'anhand', 'bisher', 'vorliegend', 'Datum', 'sein', 'Schulöffnunge', 'passieren', 'epidemiologisch', 'Einfluss', 'haben', 'haben', 'sagen', 'Klimek', 'Complexity', 'Science', 'Hub', 'CSH', 'Wien', 'medizinisch', 'Universität', 'Wien', 'forschen', 'Gespräch', 'APA', 'vergangen', 'Sonntag', 'bis', 'haben', 'Schüler', 'sonderlich', 'groß', 'Dunkelziffer', 'aufbauen', 'der', 'Sommerschule', 'sein', 'kontrollieren', 'Setting', 'Test', 'ablaufen', 'der', 'Infektionslage', 'Schüler', 'entsprechen', 'gerade', 'etwa', 'Haushalt', 'insgesamt', 'Ausgangslage', 'Diskussion', 'verkürzen', 'Quarantan', 'allein', 'Wien', 'befinden', 'aktuell', '120', 'Klasse', 'Quarantan', 'Bildungsminister', 'Heinz', 'Faßmann', 'ÖVP', 'deshalb', 'Absonderungspflicht', 'Deutschland', 'bereits', 'Fall', 'zehn', 'fünf', 'Tag', 'reduzieren', 'sofern', 'negativ', 'vorliegen', 'derzeit', 'betragen', 'Quarantänezeit', 'zwei', 'Woche', 'Freitestmöglichkeit', 'zehn', 'Tag', 'außerdem', 'laut', 'Faßmann', 'künftig', 'Fall', 'positiv', 'Testergebnis', 'mehr', 'automatisch', 'gesamt', 'Klasse', 'Quarantan', 'schicken', 'unmittelbar', 'Umfeld', 'infiziert', 'Kind', 'Sitznachbarinn', 'daheim', 'isolieren', 'Tut', 'zweiter', 'positiv', 'Fall', 'sollen', 'ungeimpft', 'Schülerin', 'Schüler', 'Heimunterricht', 'schicken', 'Gesundheitsminister', 'Wolfgang', 'Mückstein', 'grüne', 'stehen', 'Vorschlag', 'positiv', 'gegenüber', 'heißen', 'Sprich', 'Mückstein', 'unterstützen', 'Vorstoß', 'türkise', 'Koalitionspartner', 'aktuell', 'Vorschlag', 'Faßmann', 'prüfen', 'an', 'Wochenende', 'Medizinerinn', 'Mediziner', 'einheitlich', 'Quarantäneregel', 'Schule', 'aussprechen', 'Heinz', 'Faßmann', 'Vorschlag', 'ausdrücklich', 'begrüßen', 'von', 'Laer', 'Durchlaufe', 'Schule', 'der', 'Idee', 'mehr', 'gesammelt', 'Klasse', 'Quarantan', 'schicken', 'bezeichnen', 'Virologin', 'Dorothee', 'Laer', 'Innsbruck', 'Morgenjournal', 'Montag', 'weniger', 'zielführend', 'wirklich', 'Infektion', 'Klasse', 'gleich', 'Keim', 'ersticken', 'dafür', 'sein', 'ansteckend', 'sie', 'machen', 'relativ', 'wahrscheinlich', 'Kind', 'entfernt', 'sitzen', 'anstecken', 'der', 'Impfrat', 'sein', 'Österreich', 'etwa', 'Gegensatz', 'Dänemark', 'Großbritannien', 'meister', 'Maßnahme', 'Kampf', 'Pandemie', 'beenden', 'niedrig', 'noch', 'müssten', 'ungefähr', 'zehn', 'Prozent', 'mehr', 'Österreicherinn', 'Österreicher', 'Infektion', 'überstehen', 'impfen', 'lassen', 'wir', 'brauchen', 'Million', 'Immunisiert', 'Gesamtschutz', 'Pandemie', 'England', 'Dänemark', 'beenden', 'erklären', 'dann', 'können', 'Kind', 'entspannt', 'behandeln', 'in', 'Fall', 'sein', 'Risiko', 'erwachsene', 'Ältere', 'Zug', 'Schule', 'Angefacht', 'Welle', 'infizier', 'gering', 'Impfappell', 'erwachsene', 'von', 'Laer' ...
# (103, 100)

# %%
def mbkmeans_clusters(X, k, mb=500, print_silhouette_values=False):
    """Generate clusters.

    Args:
        X: Matrix of features.
        k: Number of clusters.
        mb: Size of mini-batches. Defaults to 500.
        print_silhouette_values: Print silhouette values per cluster.

    Returns:
        Trained clustering model and labels based on X.
    """
    km = MiniBatchKMeans(n_clusters=k, batch_size=mb).fit(X)
    print(f"For n_clusters = {k}")
    print(f"Silhouette coefficient: {silhouette_score(X, km.labels_):0.2f}")
    print(f"Inertia:{km.inertia_}")

    if print_silhouette_values:
        sample_silhouette_values = silhouette_samples(X, km.labels_)
        print(f"Silhouette values:")
        silhouette_values = []
        for i in range(k):
            cluster_silhouette_values = sample_silhouette_values[km.labels_ == i]
            silhouette_values.append(
                (
                    i,
                    cluster_silhouette_values.shape[0],
                    cluster_silhouette_values.mean(),
                    cluster_silhouette_values.min(),
                    cluster_silhouette_values.max(),
                )
            )
        silhouette_values = sorted(
            silhouette_values, key=lambda tup: tup[2], reverse=True
        )
        for s in silhouette_values:
            print(
                f"    Cluster {s[0]}: Size:{s[1]} | Avg:{s[2]:.2f} | Min:{s[3]:.2f} | Max: {s[4]:.2f}"
            )
    return km, km.labels_

# %%
clustering, cluster_labels = mbkmeans_clusters(X=vectorized_docs, k=5, print_silhouette_values=True)
df_clusters = pd.DataFrame({
    "text": docs,
    "tokens": [" ".join(text) for text in tokenized_docs],
    "cluster": cluster_labels
})
# Out:
# For n_clusters = 5
# Silhouette coefficient: 0.52
# Inertia:0.19440440707167328
# Silhouette values:
#     Cluster 0: Size:18 | Avg:0.54 | Min:0.10 | Max: 0.69
#     Cluster 2: Size:17 | Avg:0.53 | Min:0.15 | Max: 0.69
#     Cluster 3: Size:40 | Avg:0.51 | Min:0.02 | Max: 0.74
#     Cluster 1: Size:23 | Avg:0.50 | Min:0.05 | Max: 0.72
#     Cluster 4: Size:5 | Avg:0.49 | Min:0.36 | Max: 0.62
