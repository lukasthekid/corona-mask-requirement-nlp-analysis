# %%
import pandas as pd
import numpy as np
import codecs
import sys
import nltk
from bs4 import BeautifulSoup
import re

# %%
#doc = codecs.open('data/coronaPostings.csv','rU','UTF-16') #open for reading with "universal" type set

df = pd.read_csv('data/coronaPostings.csv', sep='\t')
print(df.shape)
df.head()
# Out:
# (13151, 10)
#                                           ID_Posting        ID_Posting_Parent  \
# 0                                         1051800287                      NaN
# 1                                         1051801262                      NaN
# 2  hält von den Schlussfolgerungen aus den Simula...  2020-03-26 16:28:10.400
# 3                                         1054666961               1054666937
# 4                                         1054667707                      NaN
#
#   ID_GodotObject ID_CommunityIdentity  id_posting_status        Headline  \
# 0  2000116189812               184470                1.0  Nicht sinnvoll
# 1  2000116189812               240940                1.0           super
# 2           True                False                NaN             NaN
# 3  2000117671399               602300                1.0             NaN
# 4  2000117671399                56623                1.0             NaN
#
# ...
