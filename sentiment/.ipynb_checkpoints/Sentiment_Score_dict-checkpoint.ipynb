# %%
import pandas as pd
import numpy as np
import spacy
from spacy_sentiws import spaCySentiWS

# %%
df = pd.read_csv('data/p_content.csv')
df.head()
# Out:
#    ID_GodotObject          author     source           publishingDate  \
# 0   2000115059032  (keine Angabe)  Redaktion  2020-02-26 16:50:27.000
# 1   2000116305030  (keine Angabe)  Redaktion  2020-03-30 05:36:31.240
# 2   2000116325081  (keine Angabe)  Redaktion  2020-03-30 13:17:32.120
# 3   2000116346340  (keine Angabe)  Redaktion  2020-03-31 05:34:39.260
# 4   2000116371728  (keine Angabe)  Redaktion  2020-03-31 16:15:23.100
#
#                                              content  \
# 0  medizinisch Personal Umgang Labor müssen Probe...
# 1  Einführung Maskenpflicht Regierung verschärfen...
# 2  Ende Sicht Regierung setzen Maske bei Einkauf ...
# 3  Supermarkt spätestens ab Montag Entscheidung M...
# 4  Clemens Auer italienisch spanisch Verhältnis v...
#
#                                            titletext
# 0  Maskenpflicht medizinisch Personal Umgang Coro...
# 1  schrittweise Einführung Maskenpflicht Öffentli...
# 2  Regierung setzen Maske bei Einkauf Test Freist...
# 3  Maskenpflicht Supermarkt spätestens ab Montag ...
# 4  Sonderbeauftragter Clemens Auer italienisch sp...

# %% [markdown]
# https://github.com/Liebeck/spacy-sentiws

# %%
nlp = spacy.load('de_core_news_sm')
nlp.add_pipe('sentiws',config={'sentiws_path': 'data/sentiws/'})
doc = nlp('Die Dummheit der Unterwerfung blüht in hübschen Farben.')

# Initialize a variable to store the overall sentiment score
sentiment_score = 0
for token in doc:
    print('{}, {}, {}'.format(token.text, token._.sentiws, token.pos_))
    sentiment_score += token._.sentiws or 0
    
print(sentiment_score)
# Out:
# Die, None, DET
# Dummheit, -0.4877, NOUN
# der, None, DET
# Unterwerfung, -0.3279, NOUN
# blüht, 0.2028, VERB
# in, None, ADP
# hübschen, 0.4629, ADJ
# Farben, None, NOUN
# ., None, PUNCT
# -0.14990000000000014

# %% [markdown]
# Now on the Whole DataFrame

# %%
def get_overall_sentiment(text):
    doc = nlp(text)
    sentiment_score = 0
    for token in doc:
        #print('{}, {}, {}'.format(token.text, token._.sentiws, token.pos_))
        sentiment_score += token._.sentiws or 0
    
    return sentiment_score / len(doc)


df['sentiment_content'] = df['content'].apply(lambda x: get_overall_sentiment(str(x)))
df['sentiment_titletext'] = df['titletext'].apply(lambda x: get_overall_sentiment(str(x)))

df.head()
# Out:
#    ID_GodotObject          author     source           publishingDate  \
# 0   2000115059032  (keine Angabe)  Redaktion  2020-02-26 16:50:27.000
# 1   2000116305030  (keine Angabe)  Redaktion  2020-03-30 05:36:31.240
# 2   2000116325081  (keine Angabe)  Redaktion  2020-03-30 13:17:32.120
# 3   2000116346340  (keine Angabe)  Redaktion  2020-03-31 05:34:39.260
# 4   2000116371728  (keine Angabe)  Redaktion  2020-03-31 16:15:23.100
#
#                                              content  \
# 0  medizinisch Personal Umgang Labor müssen Probe...
# 1  Einführung Maskenpflicht Regierung verschärfen...
# 2  Ende Sicht Regierung setzen Maske bei Einkauf ...
# 3  Supermarkt spätestens ab Montag Entscheidung M...
# 4  Clemens Auer italienisch spanisch Verhältnis v...
#
#                                            titletext  sentiment_content  \
# 0  Maskenpflicht medizinisch Personal Umgang Coro...          -0.011080
# 1  schrittweise Einführung Maskenpflicht Öffentli...          -0.001878
# 2  Regierung setzen Maske bei Einkauf Test Freist...          -0.004994
# 3  Maskenpflicht Supermarkt spätestens ab Montag ...          -0.002113
# 4  Sonderbeauftragter Clemens Auer italienisch sp...           0.000343
#
#    sentiment_titletext
# 0             0.000000
# 1             0.000000
# 2             0.000500
# 3             0.000000
# 4            -0.075214

# %%
df1 = df[['ID_GodotObject','sentiment_content','sentiment_titletext']]


df1.to_csv('data/feature/sentiws_content.csv', encoding='utf-8', index=False)
